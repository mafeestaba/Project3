# %%
import pandas as pd

# %%
df = pd.read_csv("City_zori_uc_sfrcondomfr_sm_sa_month.csv")

# %%
display(df)
# Out:
#       RegionID  SizeRank          RegionName RegionType StateName State  \
# 0         6181         0            New York       city        NY    NY
# 1        12447         1         Los Angeles       city        CA    CA
# 2        39051         2             Houston       city        TX    TX
# 3        17426         3             Chicago       city        IL    IL
# 4         6915         4         San Antonio       city        TX    TX
# ...        ...       ...                 ...        ...       ...   ...
# 3231      6618     20421              Presto       city        PA    PA
# 3232    124999     22469           Lake Hart       city        FL    FL
# 3233     47500     22678          Sagaponack       city        NY    NY
# 3234     30203     24266          Amagansett       city        NY    NY
# 3235     47768     26546  South Padre Island       city        TX    TX
#
#                                       Metro          CountyName   2015-01-31  \
# ...

# %%
tx_data = df[df['State'] == 'TX']

# %%
display(tx_data)
# Out:
#       RegionID  SizeRank          RegionName RegionType StateName State  \
# 2        39051         2             Houston       city        TX    TX
# 4         6915         4         San Antonio       city        TX    TX
# 9        38128         9              Dallas       city        TX    TX
# 10       10221        10              Austin       city        TX    TX
# 15       18172        15          Fort Worth       city        TX    TX
# ...        ...       ...                 ...        ...       ...   ...
# 3201     18809     11224               Kemah       city        TX    TX
# 3205     20303     11740        Saint Hedwig       city        TX    TX
# 3211     47663     12330          Shenandoah       city        TX    TX
# 3215     34186     13375       Sunset Valley       city        TX    TX
# 3235     47768     26546  South Padre Island       city        TX    TX
#
#                                      Metro         CountyName   2015-01-31  \
# ...

# %%
column_names = tx_data.columns.tolist()
print(column_names)
# Out:
# ['RegionID', 'SizeRank', 'RegionName', 'RegionType', 'StateName', 'State', 'Metro', 'CountyName', '2015-01-31', '2015-02-28', '2015-03-31', '2015-04-30', '2015-05-31', '2015-06-30', '2015-07-31', '2015-08-31', '2015-09-30', '2015-10-31', '2015-11-30', '2015-12-31', '2016-01-31', '2016-02-29', '2016-03-31', '2016-04-30', '2016-05-31', '2016-06-30', '2016-07-31', '2016-08-31', '2016-09-30', '2016-10-31', '2016-11-30', '2016-12-31', '2017-01-31', '2017-02-28', '2017-03-31', '2017-04-30', '2017-05-31', '2017-06-30', '2017-07-31', '2017-08-31', '2017-09-30', '2017-10-31', '2017-11-30', '2017-12-31', '2018-01-31', '2018-02-28', '2018-03-31', '2018-04-30', '2018-05-31', '2018-06-30', '2018-07-31', '2018-08-31', '2018-09-30', '2018-10-31', '2018-11-30', '2018-12-31', '2019-01-31', '2019-02-28', '2019-03-31', '2019-04-30', '2019-05-31', '2019-06-30', '2019-07-31', '2019-08-31', '2019-09-30', '2019-10-31', '2019-11-30', '2019-12-31', '2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30', '202
# ...

# %%
index_2020_01_31 = column_names.index('2020-01-31')
selected_columns = column_names[:8] + column_names[index_2020_01_31:]
filteredrental = tx_data[selected_columns]

# %%
display(filteredrental)
# Out:
#       RegionID  SizeRank          RegionName RegionType StateName State  \
# 2        39051         2             Houston       city        TX    TX
# 4         6915         4         San Antonio       city        TX    TX
# 9        38128         9              Dallas       city        TX    TX
# 10       10221        10              Austin       city        TX    TX
# 15       18172        15          Fort Worth       city        TX    TX
# ...        ...       ...                 ...        ...       ...   ...
# 3201     18809     11224               Kemah       city        TX    TX
# 3205     20303     11740        Saint Hedwig       city        TX    TX
# 3211     47663     12330          Shenandoah       city        TX    TX
# 3215     34186     13375       Sunset Valley       city        TX    TX
# 3235     47768     26546  South Padre Island       city        TX    TX
#
#                                      Metro         CountyName   2020-01-31  \
# ...

# %%
filteredrental.to_csv("tx_rental_filtered.csv", index=False)
