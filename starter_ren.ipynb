# %% [markdown]
# Import the data provided in the repository `filtered_data` and `tx_rental_filtered` file from your Terminal. Name the database `database` and the collections `home_values` and `tx_rental`.
# e.g.: Import the dataset with
# shell ```
#  `mongoimport --type csv -d database -c home_values --headerline --drop filtered_data.csv`
#  `mongoimport --type csv -d database -c tx_rental --headerline --drop tx_rental_filtered.csv`

# %%
from pymongo import MongoClient
import pandas as pd 
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'classDB', 'config', 'database', 'epa', 'fruitsDB', 'local', 'met', 'petsitly_marketing', 'uk_food']

# %%
db = mongo['database']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['tx_rental', 'cap_rates', 'home_values']

# %%
print(db.home_values.find_one())
# Out:
# {'_id': ObjectId('6614833891a1966a520b22f1'), 'RegionID': 6915, 'SizeRank': 4, 'RegionName': 'San Antonio', 'RegionType': 'city', 'StateName': 'TX', 'State': 'TX', 'Metro': 'San Antonio-New Braunfels, TX', 'CountyName': 'Bexar County', '2020-01-31': 188593.85552095255, '2020-02-29': 189721.37728223903, '2020-03-31': 190678.15418532223, '2020-04-30': 191295.32558400775, '2020-05-31': 191543.2083657508, '2020-06-30': 191729.9457597177, '2020-07-31': 192343.80810888103, '2020-08-31': 193460.5672464882, '2020-09-30': 195323.8738640512, '2020-10-31': 197633.5712736162, '2020-11-30': 200344.1026358548, '2020-12-31': 202871.53133869416, '2021-01-31': 205293.7448359781, '2021-02-28': 207753.91584310215, '2021-03-31': 210620.8061614492, '2021-04-30': 213750.32444593147, '2021-05-31': 217175.573266267, '2021-06-30': 220778.0754972015, '2021-07-31': 223994.04241285377, '2021-08-31': 226318.17184069008, '2021-09-30': 227900.48183243605, '2021-10-31': 229463.1790347068, '2021-11-30': 231811.34615763384, '2021-12-31': 234774.22566158135, '2022-01-31': 238918.0491235023, '2022-02-28': 243608.8018204978, '2022-03-31': 248747.68495791536, '2022-04-30': 253704.19388062623, '2022-05-31': 258128.77957684064, '2022-06-30': 261844.24920068705, '2022-07-31': 264195.82276450744, '2022-08-31': 265012.0489691625, '2022-09-30': 264590.99094715115, '2022-10-31': 263962.1356881464, '2022-11-30': 263369.9336730152, '2022-12-31': 262906.07243680727, '2023-01-31': 262270.9351526899, '2023-02-28': 261195.26741747747, '2023-03-31': 260007.3391497844, '2023-04-30': 258991.65111489943, '2023-05-31': 258762.80362858903, '2023-06-30': 259070.80428640152, '2023-07-31': 259292.47894103444, '2023-08-31': 259427.26891747807, '2023-09-30': 258986.00463806943, '2023-10-31': 258152.6648590546, '2023-11-30': 256904.0548186004, '2023-12-31': 255413.80488891143, '2024-01-31': 254326.87422672284, '2024-02-29': 253762.22422453552}

# %%
collection = db['home_values']
data = list(collection.find()) 
home_values_df = pd.DataFrame(data)

# Drop the MongoDB ID column if present
home_values_df.drop('_id', axis=1, inplace=True)
home_values_df
# Out:
#       RegionID  SizeRank      RegionName RegionType StateName State  \
# 0         6915         4     San Antonio       city        TX    TX
# 1        39051         2         Houston       city        TX    TX
# 2        38128         9          Dallas       city        TX    TX
# 3        10221        10          Austin       city        TX    TX
# 4        18172        15      Fort Worth       city        TX    TX
# ...        ...       ...             ...        ...       ...   ...
# 1160     40403     28683  Port Mansfield       city        TX    TX
# 1161     49589     28683            Maud       city        TX    TX
# 1162     47606     30116          Scurry       city        TX    TX
# 1163     28441     30116          Kerens       city        TX    TX
# 1164     44782     30116            Cove       city        TX    TX
#
#                                      Metro       CountyName     2020-01-31  \
# 0            San Antonio-New Braunfels, TX     Bexar County  188593.855521
# 1     Houston-The Woodlands-Sugar Land, TX    Harris County  192076.579102
# 2          Dallas-Fort Worth-Arlington, TX    Dallas County  216297.844538
# 3         Austin-Round Rock-Georgetown, TX    Travis County  382799.457978
# 4          Dallas-Fort Worth-Arlington, TX   Tarrant County  208783.526584
# ...                                    ...              ...            ...
# 1160                      Raymondville, TX   Willacy County  232810.564099
# 1161                      Texarkana, TX-AR     Bowie County
# 1162       Dallas-Fort Worth-Arlington, TX   Kaufman County   224512.91548
# 1163                         Corsicana, TX   Navarro County   77887.495225
# 1164  Houston-The Woodlands-Sugar Land, TX  Chambers County
#
#          2020-02-29  ...     2023-05-31     2023-06-30     2023-07-31  \
# 0     189721.377282  ...  258762.803629  259070.804286  259292.478941
# 1     192844.406663  ...  260877.981524  261747.058037  262686.992261
# 2     218540.208422  ...   303289.56986  303987.706238  304796.575109
# 3     386650.768544  ...   554541.44432  553270.624179  552144.143792
# 4     209978.832275  ...  302020.340768   302037.20466  302393.268898
# ...             ...  ...            ...            ...            ...
# 1160  233838.926989  ...  246431.243999  247220.857022   245609.99355
# 1161                 ...  134107.150692  135208.566723  135387.136592
# 1162  225591.010757  ...  324557.695429  324300.791991  323397.648808
# 1163   78655.145476  ...  124242.168392  124217.912176  123635.357095
# 1164                 ...  326455.628573   326955.55605  326990.668087
#
#          2023-08-31     2023-09-30     2023-10-31     2023-11-30  \
# 0     259427.268917  258986.004638  258152.664859  256904.054819
# 1     263642.221105  264097.674868  264251.215748  264097.181129
# 2     305905.538587  306650.779522  307224.973021  307227.639955
# 3     551092.695893   549462.32791  546396.907685  542487.978609
# 4     302811.122821  302913.335104  302876.714297  302707.322488
# ...             ...            ...            ...            ...
# 1160  247118.810192  248611.791946   249888.16557  250246.850381
# 1161  135037.684114  133759.102381  132015.753002   129643.59213
# 1162    322337.7027  321909.698088  322328.413155  323176.311223
# 1163  122980.808307  122556.637601  122214.748212  121371.286547
# 1164   328306.69049  329980.779637  331727.289649  333172.098114
#
#          2023-12-31     2024-01-31     2024-02-29
# 0     255413.804889  254326.874227  253762.224225
# 1     263894.500323  264115.166031  264626.193654
# 2     306828.870363  307012.266298  307990.336118
# 3     538468.134734  535738.661015  533719.132333
# 4      302479.65677  302375.650892  302358.864013
# ...             ...            ...            ...
# 1160  251433.517213  253531.027415  253298.823944
# 1161   128140.53607  127514.726467  127746.315716
# 1162  323791.841722  324416.855083  325238.923600
# 1163  120433.141594  119386.129759  119590.997333
# 1164  334076.052998  335983.382636  337913.421113
#
# [1165 rows x 58 columns]

# %%
collection = db['tx_rental']
data = list(collection.find()) 
tx_rental_df = pd.DataFrame(data)

# Drop the MongoDB ID column if present
tx_rental_df.drop('_id', axis=1, inplace=True)
tx_rental_df
# Out:
#      RegionID  SizeRank          RegionName RegionType StateName State  \
# 0       38128         9              Dallas       city        TX    TX
# 1       39051         2             Houston       city        TX    TX
# 2        6915         4         San Antonio       city        TX    TX
# 3       10221        10              Austin       city        TX    TX
# 4       18172        15          Fort Worth       city        TX    TX
# ..        ...       ...                 ...        ...       ...   ...
# 231     18809     11224               Kemah       city        TX    TX
# 232     20303     11740        Saint Hedwig       city        TX    TX
# 233     47663     12330          Shenandoah       city        TX    TX
# 234     34186     13375       Sunset Valley       city        TX    TX
# 235     47768     26546  South Padre Island       city        TX    TX
#
#                                     Metro         CountyName   2020-01-31  \
# 0         Dallas-Fort Worth-Arlington, TX      Dallas County  1360.713573
# 1    Houston-The Woodlands-Sugar Land, TX      Harris County  1319.159758
# 2           San Antonio-New Braunfels, TX       Bexar County  1151.148727
# 3        Austin-Round Rock-Georgetown, TX      Travis County  1414.446645
# 4         Dallas-Fort Worth-Arlington, TX     Tarrant County  1317.022917
# ..                                    ...                ...          ...
# 231  Houston-The Woodlands-Sugar Land, TX   Galveston County
# 232         San Antonio-New Braunfels, TX       Bexar County
# 233  Houston-The Woodlands-Sugar Land, TX  Montgomery County
# 234      Austin-Round Rock-Georgetown, TX      Travis County
# 235             Brownsville-Harlingen, TX     Cameron County
#
#       2020-02-29  ...   2023-05-31   2023-06-30   2023-07-31   2023-08-31  \
# 0    1361.234266  ...  1705.581198  1694.916395   1689.45014  1689.258107
# 1    1325.291645  ...  1546.763799   1546.57139  1547.972385  1547.961589
# 2    1154.890101  ...   1404.74928  1401.508611  1397.089617  1397.031326
# 3    1419.241049  ...  1759.814202   1744.43509  1734.160451  1726.330833
# 4    1327.468846  ...  1674.274401  1672.435786  1671.190123  1670.081755
# ..           ...  ...          ...          ...          ...          ...
# 231               ...  1431.345289  1406.709097   1368.92724  1373.112871
# 232               ...
# 233               ...                            1527.650407  1556.487909
# 234               ...
# 235               ...
#
#       2023-09-30   2023-10-31   2023-11-30   2023-12-31   2024-01-31  \
# 0    1692.513942  1701.121975  1704.075402  1708.206896  1708.551038
# 1    1551.020013  1555.491168   1561.18254  1567.743572  1570.567848
# 2    1396.316124  1398.199217  1398.066707  1397.466639  1394.041111
# 3    1721.566892  1722.491439  1725.281147  1726.529973  1724.319689
# 4    1672.852082  1678.668352  1681.947801  1682.146701  1679.387643
# ..           ...          ...          ...          ...          ...
# 231  1375.239176  1355.796887  1380.298861  1371.807133  1437.588923
# 232                             1858.74583               1879.228157
# 233  1624.968413               1788.678409  1860.282622  1894.209917
# 234
# 235
#
#       2024-02-29
# 0    1709.807306
# 1    1572.250076
# 2    1392.620914
# 3    1719.293768
# 4    1677.156930
# ..           ...
# 231  1441.222222
# 232  1911.000000
# 233  2005.555556
# 234  1619.250000
# 235  2350.000000
#
# [236 rows x 58 columns]

# %%
# Find the most recent month for each city in tx_rental_df
tx_rental_recent = tx_rental_df[['RegionName', tx_rental_df.columns[-1]]]  # Selecting the last column (most recent month)
tx_rental_recent = tx_rental_recent.rename(columns={tx_rental_df.columns[-1]: 'Recent_Month_tx_rental'})

# Find the most recent month for each city in home_values_df
home_values_recent = home_values_df[['RegionName', home_values_df.columns[-1]]]  # Selecting the last column (most recent month)
home_values_recent = home_values_recent.rename(columns={home_values_df.columns[-1]: 'Recent_Month_home_values'})

# Merge the two DataFrames based on the city column
merged_df = pd.merge(tx_rental_recent, home_values_recent, on='RegionName', how='inner')

# Display the merged DataFrame
print(merged_df)
# Out:
#              RegionName  Recent_Month_tx_rental  Recent_Month_home_values
# 0                Dallas             1709.807306             307990.336118
# 1               Houston             1572.250076             264626.193654
# 2           San Antonio             1392.620914             253762.224225
# 3                Austin             1719.293768             533719.132333
# 4            Fort Worth             1677.156930             302358.864013
# ..                  ...                     ...                       ...
# 228               Kemah             1441.222222             319180.006928
# 229        Saint Hedwig             1911.000000             289389.180552
# 230          Shenandoah             2005.555556             416391.096093
# 231       Sunset Valley             1619.250000             999838.145799
# 232  South Padre Island             2350.000000             443895.823706
#
# [233 rows x 3 columns]

# %%
merged_df['cap_rate'] = (merged_df['Recent_Month_tx_rental'] * 12) / merged_df['Recent_Month_home_values']
print(merged_df)
# Out:
#              RegionName  Recent_Month_tx_rental  Recent_Month_home_values  \
# 0                Dallas             1709.807306             307990.336118
# 1               Houston             1572.250076             264626.193654
# 2           San Antonio             1392.620914             253762.224225
# 3                Austin             1719.293768             533719.132333
# 4            Fort Worth             1677.156930             302358.864013
# ..                  ...                     ...                       ...
# 228               Kemah             1441.222222             319180.006928
# 229        Saint Hedwig             1911.000000             289389.180552
# 230          Shenandoah             2005.555556             416391.096093
# 231       Sunset Valley             1619.250000             999838.145799
# 232  South Padre Island             2350.000000             443895.823706
#
#      cap_rate
# 0    0.066618
# 1    0.071297
# 2    0.065855
# 3    0.038656
# 4    0.066563
# ..        ...
# 228  0.054185
# 229  0.079243
# 230  0.057798
# 231  0.019434
# 232  0.063528
#
# [233 rows x 4 columns]

# %%
merged_df['cap_rate'] = merged_df['cap_rate'] * 100

# %%
print(merged_df)
# Out:
#              RegionName  Recent_Month_tx_rental  Recent_Month_home_values  \
# 0                Dallas             1709.807306             307990.336118
# 1               Houston             1572.250076             264626.193654
# 2           San Antonio             1392.620914             253762.224225
# 3                Austin             1719.293768             533719.132333
# 4            Fort Worth             1677.156930             302358.864013
# ..                  ...                     ...                       ...
# 228               Kemah             1441.222222             319180.006928
# 229        Saint Hedwig             1911.000000             289389.180552
# 230          Shenandoah             2005.555556             416391.096093
# 231       Sunset Valley             1619.250000             999838.145799
# 232  South Padre Island             2350.000000             443895.823706
#
#      cap_rate
# 0    6.661796
# 1    7.129680
# 2    6.585476
# 3    3.865615
# 4    6.656290
# ..        ...
# 228  5.418468
# 229  7.924277
# 230  5.779823
# 231  1.943415
# 232  6.352842
#
# [233 rows x 4 columns]

# %%
# Load the uscities.csv file into a DataFrame
uscities_df = pd.read_csv('uscities.csv')

# Filter uscities_df to only include cities in Texas (state_id = 'TX')
uscities_df = uscities_df[uscities_df['state_id'] == 'TX']

# Rename the columns in uscities_df
uscities_df = uscities_df.rename(columns={'lat': 'latitude', 'lng': 'longitude'})

# Iterate through uscities_df and drop records that do not match any RegionName values in merged_df
for index, row in uscities_df.iterrows():
    city_name = row['city']
    if city_name not in merged_df['RegionName'].values:
        uscities_df = uscities_df.drop(index)

# Merge the DataFrames
merged_df = pd.merge(merged_df, uscities_df[['city', 'latitude', 'longitude']], how='inner', left_on='RegionName', right_on='city')

# Drop the duplicate 'city' column if needed
merged_df = merged_df.drop('city', axis=1)

# Display the updated DataFrame
print(merged_df)
# Out:
#              RegionName  Recent_Month_tx_rental  Recent_Month_home_values  \
# 0                Dallas             1709.807306             307990.336118
# 1               Houston             1572.250076             264626.193654
# 2           San Antonio             1392.620914             253762.224225
# 3                Austin             1719.293768             533719.132333
# 4            Fort Worth             1677.156930             302358.864013
# ..                  ...                     ...                       ...
# 221         Hudson Oaks             1470.750000             525745.724486
# 222               Kemah             1441.222222             319180.006928
# 223          Shenandoah             2005.555556             416391.096093
# 224       Sunset Valley             1619.250000             999838.145799
# 225  South Padre Island             2350.000000             443895.823706
#
#      cap_rate  latitude  longitude
# 0    6.661796   32.7935   -96.7667
# 1    7.129680   29.7860   -95.3885
# 2    6.585476   29.4632   -98.5238
# 3    3.865615   30.3005   -97.7522
# 4    6.656290   32.7817   -97.3474
# ..        ...       ...        ...
# 221  3.356946   32.7509   -97.7001
# 222  5.418468   29.5309   -95.0196
# 223  5.779823   30.1840   -95.4557
# 224  1.943415   30.2258   -97.8158
# 225  6.352842   26.1218   -97.1703
#
# [226 rows x 6 columns]

# %%
# # Drop one set of latitude and longitude columns
# merged_df = merged_df.drop(['latitude_x', 'longitude_x'], axis=1)

# # Rename the remaining latitude and longitude columns
# merged_df = merged_df.rename(columns={'latitude_y': 'latitude', 'longitude_y': 'longitude'})

# # Display the updated DataFrame
# print(merged_df.head())

# %%
top_10_rental_cities = merged_df.nlargest(10, 'Recent_Month_tx_rental')['RegionName']
print("Top 10 cities by Recent_Month_tx_rental:")
print(top_10_rental_cities)
# Out:
# Top 10 cities by Recent_Month_tx_rental:
# 141       University Park
# 211           Trophy Club
# 183               Lakeway
# 129             Southlake
# 219           Iowa Colony
# 217                 Lavon
# 164       Timberwood Park
# 181               Red Oak
# 188         Glenn Heights
# 225    South Padre Island
# Name: RegionName, dtype: object

# %%
top_10_home_values_cities = merged_df.nlargest(10, 'Recent_Month_home_values')['RegionName']
print("\nTop 10 cities by Recent_Month_home_values:")
print(top_10_home_values_cities)
# Out:
# Top 10 cities by Recent_Month_home_values:
# 141     University Park
# 129           Southlake
# 173            Bellaire
# 224       Sunset Valley
# 204            Bee Cave
# 123             Prosper
# 183             Lakeway
# 160    Dripping Springs
# 213       Alamo Heights
# 211         Trophy Club
# Name: RegionName, dtype: object

# %%
top_10_cap_rate_cities = merged_df.nlargest(10, 'cap_rate')['RegionName']
print("\nTop 10 cities by cap_rate:")
print(top_10_cap_rate_cities)
# Out:
# Top 10 cities by cap_rate:
# 75          Port Arthur
# 32             Beaumont
# 171              Groves
# 153           Corsicana
# 172    White Settlement
# 198           Hitchcock
# 174           La Marque
# 117              Orange
# 124          Big Spring
# 219         Iowa Colony
# Name: RegionName, dtype: object

# %%
# Get the top 10 cities by Recent_Month_home_values
top_10_home_values_cities = merged_df.nlargest(10, 'Recent_Month_home_values')['RegionName']

# Filter the DataFrame for the top 10 cities and select the RegionName and cap_rate columns
top_10_cap_rate_df = merged_df.loc[merged_df['RegionName'].isin(top_10_home_values_cities), ['RegionName', 'cap_rate']]

print(top_10_cap_rate_df)
# Out:
#            RegionName  cap_rate
# 123           Prosper  2.592880
# 129         Southlake  2.711911
# 141   University Park  2.222430
# 160  Dripping Springs  3.434662
# 173          Bellaire  2.632616
# 183           Lakeway  4.469184
# 204          Bee Cave  2.690283
# 211       Trophy Club  5.311621
# 213     Alamo Heights  2.814823
# 224     Sunset Valley  1.943415

# %%
records = merged_df.to_dict(orient='records')
# Specify the database name, or create it if it doesn't exist
db = mongo['database']
# Specify the collection name. This creates a new collection if it doesn't already exist

collection = db['cap_rates']

collection.drop()

# Insert the records into the collection
collection.insert_many(records)

# %%
cap_rates_collection = db["cap_rates"]

# Find all documents in the cap_rates collection
cursor = cap_rates_collection.find()

for document in cursor:
    print(document)
# Out:
# {'_id': ObjectId('6617354d90c281365cdfd455'), 'RegionName': 'Dallas', 'Recent_Month_tx_rental': 1709.8073064244652, 'Recent_Month_home_values': 307990.3361180607, 'cap_rate': 6.661795930255623, 'latitude': 32.7935, 'longitude': -96.7667}
# {'_id': ObjectId('6617354d90c281365cdfd456'), 'RegionName': 'Houston', 'Recent_Month_tx_rental': 1572.2500761629317, 'Recent_Month_home_values': 264626.193653876, 'cap_rate': 7.12968004166387, 'latitude': 29.786, 'longitude': -95.3885}
# {'_id': ObjectId('6617354d90c281365cdfd457'), 'RegionName': 'San Antonio', 'Recent_Month_tx_rental': 1392.6209143469002, 'Recent_Month_home_values': 253762.22422453552, 'cap_rate': 6.5854762359649195, 'latitude': 29.4632, 'longitude': -98.5238}
# {'_id': ObjectId('6617354d90c281365cdfd458'), 'RegionName': 'Austin', 'Recent_Month_tx_rental': 1719.2937680843927, 'Recent_Month_home_values': 533719.1323332309, 'cap_rate': 3.86561469640764, 'latitude': 30.3005, 'longitude': -97.7522}
# {'_id': ObjectId('6617354d90c281365cdfd459'), 'RegionName': 'Fort Worth', 'Recent_Month_tx_rental': 1677.156929963422, 'Recent_Month_home_values': 302358.8640129177, 'cap_rate': 6.656290109193301, 'latitude': 32.7817, 'longitude': -97.3474}
# {'_id': ObjectId('6617354d90c281365cdfd45a'), 'RegionName': 'El Paso', 'Recent_Month_tx_rental': 1511.309130815897, 'Recent_Month_home_values': 216672.89338164683, 'cap_rate': 8.370086948461335, 'latitude': 31.8476, 'longitude': -106.43}
# {'_id': ObjectId('6617354d90c281365cdfd45b'), 'RegionName': 'Corpus Christi', 'Recent_Month_tx_rental': 1454.1766602192135, 'Recent_Month_home_values': 214379.68438172483, 'cap_rate': 8.1398197655515, 'latitude': 27.7254, 'longitude': -97.3767}
# {'_id': ObjectId('6617354d90c281365cdfd45c'), 'RegionName': 'Plano', 'Recent_Month_tx_rental': 1780.6014288335398, 'Recent_Month_home_values': 520694.7336303989, 'cap_rate': 4.103597706284738, 'latitude': 33.0502, 'longitude': -96.7486}
# {'_id': ObjectId('6617354d90c281365cdfd45d'), 'RegionName': 'Spring', 'Recent_Month_tx_rental': 1726.3401025479827, 'Recent_Month_home_values': 358530.821439294, 'cap_rate': 5.77804751831731, 'latitude': 30.0613, 'longitude': -95.383}
# {'_id': ObjectId('6617354d90c281365cdfd45e'), 'RegionName': 'Arlington', 'Recent_Month_tx_rental': 1586.3892047069155, 'Recent_Month_home_values': 315222.1987008148, 'cap_rate': 6.039127490050649, 'latitude': 32.6998, 'longitude': -97.125}
# {'_id': ObjectId('6617354d90c281365cdfd45f'), 'RegionName': 'Lubbock', 'Recent_Month_tx_rental': 1332.0667766602417, 'Recent_Month_home_values': 204531.8509233269, 'cap_rate': 7.815311526181387, 'latitude': 33.5657, 'longitude': -101.8879}
# {'_id': ObjectId('6617354d90c281365cdfd460'), 'RegionName': 'Katy', 'Recent_Month_tx_rental': 1891.574709632644, 'Recent_Month_home_values': 344619.07219458494, 'cap_rate': 6.5866628828874205, 'latitude': 29.7905, 'longitude': -95.8353}
# {'_id': ObjectId('6617354d90c281365cdfd461'), 'RegionName': 'Laredo', 'Recent_Month_tx_rental': 1187.2857142857144, 'Recent_Month_home_values': 203832.3046838251, 'cap_rate': 6.989779462842508, 'latitude': 27.5625, 'longitude': -99.4874}
# {'_id': ObjectId('6617354d90c281365cdfd462'), 'RegionName': 'Irving', 'Recent_Month_tx_rental': 1628.6758579680595, 'Recent_Month_home_values': 344587.4026461356, 'cap_rate': 5.671742537752314, 'latitude': 32.8583, 'longitude': -96.9702}
# {'_id': ObjectId('6617354d90c281365cdfd463'), 'RegionName': 'Garland', 'Recent_Month_tx_rental': 1640.8700466200469, 'Recent_Month_home_values': 300324.67922925664, 'cap_rate': 6.556384446983664, 'latitude': 32.91, 'longitude': -96.6304}
# {'_id': ObjectId('6617354d90c281365cdfd464'), 'RegionName': 'Amarillo', 'Recent_Month_tx_rental': 1338.9825708061, 'Recent_Month_home_values': 194789.99776760975, 'cap_rate': 8.248776135231827, 'latitude': 35.1984, 'longitude': -101.8316}
# {'_id': ObjectId('6617354d90c281365cdfd465'), 'RegionName': 'Brownsville', 'Recent_Month_tx_rental': 1333.5396825396826, 'Recent_Month_home_values': 180139.29445592896, 'cap_rate': 8.883390067007948, 'latitude': 25.9975, 'longitude': -97.458}
# {'_id': ObjectId('6617354d90c281365cdfd466'), 'RegionName': 'Frisco', 'Recent_Month_tx_rental': 1869.4667084377609, 'Recent_Month_home_values': 674493.1715154328, 'cap_rate': 3.3259937162669764, 'latitude': 33.156, 'longitude': -96.8216}
# {'_id': ObjectId('6617354d90c281365cdfd467'), 'RegionName': 'McKinney', 'Recent_Month_tx_rental': 1806.8289420625035, 'Recent_Month_home_values': 517976.02557041706, 'cap_rate': 4.1858978474675475, 'latitude': 33.2016, 'longitude': -96.667}
# {'_id': ObjectId('6617354d90c281365cdfd468'), 'RegionName': 'Grand Prairie', 'Recent_Month_tx_rental': 1603.6782815104732, 'Recent_Month_home_values': 319174.56577844906, 'cap_rate': 6.029346145169898, 'latitude': 32.6871, 'longitude': -97.0208}
# {'_id': ObjectId('6617354d90c281365cdfd469'), 'RegionName': 'Killeen', 'Recent_Month_tx_rental': 1265.142803452586, 'Recent_Month_home_values': 223329.16968765072, 'cap_rate': 6.797908962212258, 'latitude': 31.0753, 'longitude': -97.7297}
# {'_id': ObjectId('6617354d90c281365cdfd46a'), 'RegionName': 'Round Rock', 'Recent_Month_tx_rental': 1773.8905501384372, 'Recent_Month_home_values': 439423.3178821188, 'cap_rate': 4.8442323689731195, 'latitude': 30.527, 'longitude': -97.6642}
# {'_id': ObjectId('6617354d90c281365cdfd46b'), 'RegionName': 'Conroe', 'Recent_Month_tx_rental': 1624.6381399559366, 'Recent_Month_home_values': 318553.71251079004, 'cap_rate': 6.120053514934591, 'latitude': 30.3238, 'longitude': -95.4824}
# {'_id': ObjectId('6617354d90c281365cdfd46c'), 'RegionName': 'Sugar Land', 'Recent_Month_tx_rental': 2014.1069168836607, 'Recent_Month_home_values': 439538.9432846673, 'cap_rate': 5.49878079561899, 'latitude': 29.5935, 'longitude': -95.6358}
# {'_id': ObjectId('6617354d90c281365cdfd46d'), 'RegionName': 'Edinburg', 'Recent_Month_tx_rental': 965.938522777532, 'Recent_Month_home_values': 200379.5492906017, 'cap_rate': 5.7846533313237884, 'latitude': 26.3196, 'longitude': -98.1597}
# {'_id': ObjectId('6617354d90c281365cdfd46e'), 'RegionName': 'Midland', 'Recent_Month_tx_rental': 1563.6448051948053, 'Recent_Month_home_values': 293377.05945511727, 'cap_rate': 6.3957753538013975, 'latitude': 32.0243, 'longitude': -102.1147}
# {'_id': ObjectId('6617354d90c281365cdfd46f'), 'RegionName': 'Odessa', 'Recent_Month_tx_rental': 1484.7374913733609, 'Recent_Month_home_values': 215542.1712262405, 'cap_rate': 8.266062179441976, 'latitude': 31.8801, 'longitude': -102.3448}
# {'_id': ObjectId('6617354d90c281365cdfd470'), 'RegionName': 'Tyler', 'Recent_Month_tx_rental': 1380.6460317460317, 'Recent_Month_home_values': 245911.95398650557, 'cap_rate': 6.737270031964993, 'latitude': 32.3184, 'longitude': -95.3062}
# {'_id': ObjectId('6617354d90c281365cdfd471'), 'RegionName': 'Mesquite', 'Recent_Month_tx_rental': 1725.8062453592938, 'Recent_Month_home_values': 273202.58318721334, 'cap_rate': 7.580336431196964, 'latitude': 32.7602, 'longitude': -96.5865}
# {'_id': ObjectId('6617354d90c281365cdfd472'), 'RegionName': 'Pasadena', 'Recent_Month_tx_rental': 1501.314814814815, 'Recent_Month_home_values': 216476.1019022737, 'cap_rate': 8.3222940636241, 'latitude': 29.6575, 'longitude': -95.1498}
# {'_id': ObjectId('6617354d90c281365cdfd473'), 'RegionName': 'Denton', 'Recent_Month_tx_rental': 1603.5928617238142, 'Recent_Month_home_values': 360250.9921929701, 'cap_rate': 5.3415853828871915, 'latitude': 33.2175, 'longitude': -97.1418}
# {'_id': ObjectId('6617354d90c281365cdfd474'), 'RegionName': 'Richmond', 'Recent_Month_tx_rental': 1832.04649024024, 'Recent_Month_home_values': 383404.15959382855, 'cap_rate': 5.734042610850368, 'latitude': 29.5824, 'longitude': -95.7563}
# {'_id': ObjectId('6617354d90c281365cdfd475'), 'RegionName': 'Beaumont', 'Recent_Month_tx_rental': 1160.3698232323231, 'Recent_Month_home_values': 142254.78608892788, 'cap_rate': 9.788379190337595, 'latitude': 30.0849, 'longitude': -94.1451}
# {'_id': ObjectId('6617354d90c281365cdfd476'), 'RegionName': 'McAllen', 'Recent_Month_tx_rental': 1453.6599326599326, 'Recent_Month_home_values': 219666.4966923912, 'cap_rate': 7.941092271502235, 'latitude': 26.2252, 'longitude': -98.2467}
# {'_id': ObjectId('6617354d90c281365cdfd477'), 'RegionName': 'Abilene', 'Recent_Month_tx_rental': 1265.731884057971, 'Recent_Month_home_values': 190696.3364550819, 'cap_rate': 7.964905299726792, 'latitude': 32.4543, 'longitude': -99.7384}
# {'_id': ObjectId('6617354d90c281365cdfd478'), 'RegionName': 'Pearland', 'Recent_Month_tx_rental': 1791.9034252297408, 'Recent_Month_home_values': 368045.5103668799, 'cap_rate': 5.842440811551308, 'latitude': 29.5581, 'longitude': -95.3218}
# {'_id': ObjectId('6617354d90c281365cdfd479'), 'RegionName': 'Carrollton', 'Recent_Month_tx_rental': 1799.0598684614913, 'Recent_Month_home_values': 417691.7512325561, 'cap_rate': 5.168576673547487, 'latitude': 32.989, 'longitude': -96.8999}
# {'_id': ObjectId('6617354d90c281365cdfd47a'), 'RegionName': 'College Station', 'Recent_Month_tx_rental': 1728.1289709083187, 'Recent_Month_home_values': 334964.6080132512, 'cap_rate': 6.190966793148322, 'latitude': 30.5852, 'longitude': -96.2959}
# {'_id': ObjectId('6617354d90c281365cdfd47b'), 'RegionName': 'Lewisville', 'Recent_Month_tx_rental': 1657.6325133349255, 'Recent_Month_home_values': 402071.93726511445, 'cap_rate': 4.947271449811026, 'latitude': 33.0454, 'longitude': -96.9815}
# {'_id': ObjectId('6617354d90c281365cdfd47c'), 'RegionName': 'New Braunfels', 'Recent_Month_tx_rental': 1642.8549265450863, 'Recent_Month_home_values': 356419.3067529251, 'cap_rate': 5.531198435388697, 'latitude': 29.6994, 'longitude': -98.1148}
# {'_id': ObjectId('6617354d90c281365cdfd47d'), 'RegionName': 'Waco', 'Recent_Month_tx_rental': 1372.4263157894736, 'Recent_Month_home_values': 191242.93893979877, 'cap_rate': 8.61162031956536, 'latitude': 31.5599, 'longitude': -97.1882}
# {'_id': ObjectId('6617354d90c281365cdfd47e'), 'RegionName': 'Richardson', 'Recent_Month_tx_rental': 1812.521464646465, 'Recent_Month_home_values': 445760.70078042574, 'cap_rate': 4.879357363194606, 'latitude': 32.9716, 'longitude': -96.7093}
# {'_id': ObjectId('6617354d90c281365cdfd47f'), 'RegionName': 'League City', 'Recent_Month_tx_rental': 1900.063364197531, 'Recent_Month_home_values': 362473.0296503262, 'cap_rate': 6.290332936595592, 'latitude': 29.4874, 'longitude': -95.1087}
# {'_id': ObjectId('6617354d90c281365cdfd480'), 'RegionName': 'Pflugerville', 'Recent_Month_tx_rental': 1813.5862369337976, 'Recent_Month_home_values': 401255.8385977433, 'cap_rate': 5.4237303858954915, 'latitude': 30.4515, 'longitude': -97.6018}
# {'_id': ObjectId('6617354d90c281365cdfd481'), 'RegionName': 'Baytown', 'Recent_Month_tx_rental': 1516.888003131051, 'Recent_Month_home_values': 237853.1113290908, 'cap_rate': 7.652898015863087, 'latitude': 29.7587, 'longitude': -94.9671}
# {'_id': ObjectId('6617354d90c281365cdfd482'), 'RegionName': 'Missouri City', 'Recent_Month_tx_rental': 1948.180361033302, 'Recent_Month_home_values': 351742.47010680527, 'cap_rate': 6.64638658087007, 'latitude': 29.563, 'longitude': -95.5365}
# {'_id': ObjectId('6617354d90c281365cdfd483'), 'RegionName': 'Wichita Falls', 'Recent_Month_tx_rental': 1164.2333333333331, 'Recent_Month_home_values': 160881.58102973903, 'cap_rate': 8.683902725581426, 'latitude': 33.9072, 'longitude': -98.5291}
# {'_id': ObjectId('6617354d90c281365cdfd484'), 'RegionName': 'Longview', 'Recent_Month_tx_rental': 1160.325925925926, 'Recent_Month_home_values': 220329.83881601467, 'cap_rate': 6.31957577145881, 'latitude': 32.5193, 'longitude': -94.7622}
# {'_id': ObjectId('6617354d90c281365cdfd485'), 'RegionName': 'Bryan', 'Recent_Month_tx_rental': 1420.408920940171, 'Recent_Month_home_values': 256597.88784247093, 'cap_rate': 6.642652905134653, 'latitude': 30.665, 'longitude': -96.3807}
# {'_id': ObjectId('6617354d90c281365cdfd486'), 'RegionName': 'Georgetown', 'Recent_Month_tx_rental': 1664.504428721174, 'Recent_Month_home_values': 439918.1190256949, 'cap_rate': 4.5404024705532615, 'latitude': 30.666, 'longitude': -97.6966}
# {'_id': ObjectId('6617354d90c281365cdfd487'), 'RegionName': 'Allen', 'Recent_Month_tx_rental': 1787.7454045083086, 'Recent_Month_home_values': 517802.0346540427, 'cap_rate': 4.143078516180993, 'latitude': 33.1088, 'longitude': -96.6735}
# {'_id': ObjectId('6617354d90c281365cdfd488'), 'RegionName': 'Tomball', 'Recent_Month_tx_rental': 1846.7644601700329, 'Recent_Month_home_values': 353466.15050429007, 'cap_rate': 6.269673486534157, 'latitude': 30.0951, 'longitude': -95.6194}
# {'_id': ObjectId('6617354d90c281365cdfd489'), 'RegionName': 'San Angelo', 'Recent_Month_tx_rental': 1342.6767676767677, 'Recent_Month_home_values': 206032.01451710952, 'cap_rate': 7.820202724263132, 'latitude': 31.4424, 'longitude': -100.4504}
# {'_id': ObjectId('6617354d90c281365cdfd48a'), 'RegionName': 'Humble', 'Recent_Month_tx_rental': 1783.75945618522, 'Recent_Month_home_values': 260029.6881414184, 'cap_rate': 8.231796002686188, 'latitude': 29.9921, 'longitude': -95.2655}
# {'_id': ObjectId('6617354d90c281365cdfd48b'), 'RegionName': 'Harlingen', 'Recent_Month_tx_rental': 1229.9170875420875, 'Recent_Month_home_values': 183401.0782627156, 'cap_rate': 8.047392736352014, 'latitude': 26.1916, 'longitude': -97.6977}
# {'_id': ObjectId('6617354d90c281365cdfd48c'), 'RegionName': 'Victoria', 'Recent_Month_tx_rental': 1097.475, 'Recent_Month_home_values': 203432.5254116032, 'cap_rate': 6.473743553718298, 'latitude': 28.8287, 'longitude': -96.9849}
# {'_id': ObjectId('6617354d90c281365cdfd48d'), 'RegionName': 'Mission', 'Recent_Month_tx_rental': 1498.501984126984, 'Recent_Month_home_values': 207900.74757520048, 'cap_rate': 8.649331000129989, 'latitude': 26.2039, 'longitude': -98.3256}
# {'_id': ObjectId('6617354d90c281365cdfd48e'), 'RegionName': 'Cedar Park', 'Recent_Month_tx_rental': 1718.9252466752469, 'Recent_Month_home_values': 493241.42378863785, 'cap_rate': 4.181948629063649, 'latitude': 30.5105, 'longitude': -97.8197}
# {'_id': ObjectId('6617354d90c281365cdfd48f'), 'RegionName': 'Temple', 'Recent_Month_tx_rental': 1487.3689224906263, 'Recent_Month_home_values': 252523.4833680198, 'cap_rate': 7.068026637299224, 'latitude': 31.1068, 'longitude': -97.3891}
# {'_id': ObjectId('6617354d90c281365cdfd490'), 'RegionName': 'Pharr', 'Recent_Month_tx_rental': 1094.5151515151515, 'Recent_Month_home_values': 159806.83505333227, 'cap_rate': 8.218786019883662, 'latitude': 26.1685, 'longitude': -98.1904}
# {'_id': ObjectId('6617354d90c281365cdfd491'), 'RegionName': 'San Marcos', 'Recent_Month_tx_rental': 1559.6525925925926, 'Recent_Month_home_values': 332418.03687128075, 'cap_rate': 5.630209265196483, 'latitude': 29.8734, 'longitude': -97.9356}
# {'_id': ObjectId('6617354d90c281365cdfd492'), 'RegionName': 'Leander', 'Recent_Month_tx_rental': 1834.834748421376, 'Recent_Month_home_values': 453960.6978619429, 'cap_rate': 4.850203351249707, 'latitude': 30.5728, 'longitude': -97.8618}
# {'_id': ObjectId('6617354d90c281365cdfd493'), 'RegionName': 'Flower Mound', 'Recent_Month_tx_rental': 2252.6689443454147, 'Recent_Month_home_values': 603403.2025815988, 'cap_rate': 4.479927719390819, 'latitude': 33.0343, 'longitude': -97.1146}
# {'_id': ObjectId('6617354d90c281365cdfd494'), 'RegionName': 'North Richland Hills', 'Recent_Month_tx_rental': 1615.5730573710964, 'Recent_Month_home_values': 366087.8890542407, 'cap_rate': 5.295689168668657, 'latitude': 32.8604, 'longitude': -97.218}
# {'_id': ObjectId('6617354d90c281365cdfd495'), 'RegionName': 'Mansfield', 'Recent_Month_tx_rental': 1776.8257850241546, 'Recent_Month_home_values': 437372.4253766512, 'cap_rate': 4.875000842114842, 'latitude': 32.569, 'longitude': -97.1213}
# {'_id': ObjectId('6617354d90c281365cdfd496'), 'RegionName': 'Huntsville', 'Recent_Month_tx_rental': 1109.0277777777776, 'Recent_Month_home_values': 247368.8928329123, 'cap_rate': 5.37995427837508, 'latitude': 30.7009, 'longitude': -95.5567}
# {'_id': ObjectId('6617354d90c281365cdfd497'), 'RegionName': 'Atascocita', 'Recent_Month_tx_rental': 1844.8641666666665, 'Recent_Month_home_values': 312081.2268282304, 'cap_rate': 7.0937845973622, 'latitude': 29.9777, 'longitude': -95.1953}
# {'_id': ObjectId('6617354d90c281365cdfd498'), 'RegionName': 'Weatherford', 'Recent_Month_tx_rental': 1728.7425925925927, 'Recent_Month_home_values': 376275.66798792407, 'cap_rate': 5.513221522412362, 'latitude': 32.7536, 'longitude': -97.7723}
# {'_id': ObjectId('6617354d90c281365cdfd499'), 'RegionName': 'Little Elm', 'Recent_Month_tx_rental': 2327.026984126984, 'Recent_Month_home_values': 433679.4941293758, 'cap_rate': 6.438931097164902, 'latitude': 33.1858, 'longitude': -96.9295}
# {'_id': ObjectId('6617354d90c281365cdfd49a'), 'RegionName': 'Lufkin', 'Recent_Month_tx_rental': 1187.5, 'Recent_Month_home_values': 180985.61403354257, 'cap_rate': 7.873553970626089, 'latitude': 31.3217, 'longitude': -94.7277}
# {'_id': ObjectId('6617354d90c281365cdfd49b'), 'RegionName': 'Euless', 'Recent_Month_tx_rental': 1787.452485380117, 'Recent_Month_home_values': 355992.68215130054, 'cap_rate': 6.025244590686608, 'latitude': 32.8508, 'longitude': -97.08}
# {'_id': ObjectId('6617354d90c281365cdfd49c'), 'RegionName': 'Wylie', 'Recent_Month_tx_rental': 1881.9207905384376, 'Recent_Month_home_values': 436656.6962822655, 'cap_rate': 5.171808809697727, 'latitude': 33.0362, 'longitude': -96.5161}
# {'_id': ObjectId('6617354d90c281365cdfd49d'), 'RegionName': 'Texarkana', 'Recent_Month_tx_rental': 1113.888888888889, 'Recent_Month_home_values': 184427.2875131241, 'cap_rate': 7.247662125766221, 'latitude': 33.45, 'longitude': -94.0847}
# {'_id': ObjectId('6617354d90c281365cdfd49e'), 'RegionName': 'Waxahachie', 'Recent_Month_tx_rental': 1758.181818181818, 'Recent_Month_home_values': 356064.8477437975, 'cap_rate': 5.925376220615514, 'latitude': 32.4035, 'longitude': -96.8446}
# {'_id': ObjectId('6617354d90c281365cdfd49f'), 'RegionName': 'Nacogdoches', 'Recent_Month_tx_rental': 903.7857142857142, 'Recent_Month_home_values': 200012.01268094324, 'cap_rate': 5.4223885985933595, 'latitude': 31.6134, 'longitude': -94.6528}
# {'_id': ObjectId('6617354d90c281365cdfd4a0'), 'RegionName': 'Port Arthur', 'Recent_Month_tx_rental': 1060.5, 'Recent_Month_home_values': 94825.26182802748, 'cap_rate': 13.420474412271624, 'latitude': 29.8554, 'longitude': -93.9264}
# {'_id': ObjectId('6617354d90c281365cdfd4a1'), 'RegionName': 'Rowlett', 'Recent_Month_tx_rental': 1863.7551759834369, 'Recent_Month_home_values': 385840.2282640422, 'cap_rate': 5.796456790528372, 'latitude': 32.9155, 'longitude': -96.5489}
# {'_id': ObjectId('6617354d90c281365cdfd4a2'), 'RegionName': 'Rosenberg', 'Recent_Month_tx_rental': 1859.936507936508, 'Recent_Month_home_values': 305420.24580405286, 'cap_rate': 7.307714011060469, 'latitude': 29.5456, 'longitude': -95.8223}
# {'_id': ObjectId('6617354d90c281365cdfd4a3'), 'RegionName': 'Galveston', 'Recent_Month_tx_rental': 1356.6312169312168, 'Recent_Month_home_values': 343334.2007045861, 'cap_rate': 4.741611691979961, 'latitude': 29.2484, 'longitude': -94.8913}
# {'_id': ObjectId('6617354d90c281365cdfd4a4'), 'RegionName': 'Granbury', 'Recent_Month_tx_rental': 1632.952380952381, 'Recent_Month_home_values': 361234.35418160725, 'cap_rate': 5.424575028535949, 'latitude': 32.4475, 'longitude': -97.7702}
# {'_id': ObjectId('6617354d90c281365cdfd4a5'), 'RegionName': 'Kyle', 'Recent_Month_tx_rental': 1685.689393939394, 'Recent_Month_home_values': 332106.69956358144, 'cap_rate': 6.0908957132917, 'latitude': 29.9932, 'longitude': -97.8852}
# {'_id': ObjectId('6617354d90c281365cdfd4a6'), 'RegionName': 'Forney', 'Recent_Month_tx_rental': 2127.1779431140044, 'Recent_Month_home_values': 332624.6771571377, 'cap_rate': 7.674155608517603, 'latitude': 32.744, 'longitude': -96.4529}
# {'_id': ObjectId('6617354d90c281365cdfd4a7'), 'RegionName': 'Boerne', 'Recent_Month_tx_rental': 1636.5277777777776, 'Recent_Month_home_values': 547854.1596042643, 'cap_rate': 3.584591444467418, 'latitude': 29.7847, 'longitude': -98.7292}
# {'_id': ObjectId('6617354d90c281365cdfd4a8'), 'RegionName': 'Sherman', 'Recent_Month_tx_rental': 1456.2214285714288, 'Recent_Month_home_values': 253139.3762183317, 'cap_rate': 6.903176188514158, 'latitude': 33.6273, 'longitude': -96.6221}
# {'_id': ObjectId('6617354d90c281365cdfd4a9'), 'RegionName': 'Grapevine', 'Recent_Month_tx_rental': 1813.4281537176275, 'Recent_Month_home_values': 534778.9507851579, 'cap_rate': 4.069183690319527, 'latitude': 32.9343, 'longitude': -97.0742}
# {'_id': ObjectId('6617354d90c281365cdfd4aa'), 'RegionName': 'Montgomery', 'Recent_Month_tx_rental': 1800.3160173160177, 'Recent_Month_home_values': 377548.5626345223, 'cap_rate': 5.722122753439083, 'latitude': 30.3921, 'longitude': -95.6958}
# {'_id': ObjectId('6617354d90c281365cdfd4ab'), 'RegionName': 'Eagle Pass', 'Recent_Month_tx_rental': 1225.0, 'Recent_Month_home_values': 192982.7096501199, 'cap_rate': 7.617262720920069, 'latitude': 28.7125, 'longitude': -100.484}
# {'_id': ObjectId('6617354d90c281365cdfd4ac'), 'RegionName': 'Seguin', 'Recent_Month_tx_rental': 1528.8333333333333, 'Recent_Month_home_values': 283512.00909814524, 'cap_rate': 6.470978093082838, 'latitude': 29.5891, 'longitude': -97.9676}
# {'_id': ObjectId('6617354d90c281365cdfd4ad'), 'RegionName': 'Cedar Hill', 'Recent_Month_tx_rental': 1946.2991452991453, 'Recent_Month_home_values': 311391.9798772459, 'cap_rate': 7.500382557314665, 'latitude': 32.581, 'longitude': -96.9591}
# {'_id': ObjectId('6617354d90c281365cdfd4ae'), 'RegionName': 'Weslaco', 'Recent_Month_tx_rental': 985.5555555555557, 'Recent_Month_home_values': 170482.03123688838, 'cap_rate': 6.937192489355823, 'latitude': 26.1599, 'longitude': -97.9877}
# {'_id': ObjectId('6617354d90c281365cdfd4af'), 'RegionName': 'Bedford', 'Recent_Month_tx_rental': 1633.27962962963, 'Recent_Month_home_values': 371403.23298298864, 'cap_rate': 5.277109571217241, 'latitude': 32.8464, 'longitude': -97.135}
# {'_id': ObjectId('6617354d90c281365cdfd4b0'), 'RegionName': 'Cleveland', 'Recent_Month_tx_rental': 1523.3333333333333, 'Recent_Month_home_values': 223542.28394942335, 'cap_rate': 8.177423830981287, 'latitude': 30.3381, 'longitude': -95.0908}
# {'_id': ObjectId('6617354d90c281365cdfd4b1'), 'RegionName': 'Cleburne', 'Recent_Month_tx_rental': 1454.888888888889, 'Recent_Month_home_values': 255205.0187834147, 'cap_rate': 6.84103578757726, 'latitude': 32.3568, 'longitude': -97.4151}
# {'_id': ObjectId('6617354d90c281365cdfd4b2'), 'RegionName': 'Texas City', 'Recent_Month_tx_rental': 1435.0449134199134, 'Recent_Month_home_values': 207327.6610862217, 'cap_rate': 8.305953422142466, 'latitude': 29.4154, 'longitude': -94.9682}
# {'_id': ObjectId('6617354d90c281365cdfd4b3'), 'RegionName': 'Alvin', 'Recent_Month_tx_rental': 1537.222222222222, 'Recent_Month_home_values': 273841.8634044206, 'cap_rate': 6.736247861205899, 'latitude': 29.3872, 'longitude': -95.2938}
# {'_id': ObjectId('6617354d90c281365cdfd4b4'), 'RegionName': 'Rockwall', 'Recent_Month_tx_rental': 1912.9186324786324, 'Recent_Month_home_values': 464190.3268604684, 'cap_rate': 4.945174912411233, 'latitude': 32.9169, 'longitude': -96.4374}
# {'_id': ObjectId('6617354d90c281365cdfd4b5'), 'RegionName': 'Converse', 'Recent_Month_tx_rental': 1693.8861421229842, 'Recent_Month_home_values': 255504.09471870423, 'cap_rate': 7.955502133088826, 'latitude': 29.5091, 'longitude': -98.3084}
# {'_id': ObjectId('6617354d90c281365cdfd4b6'), 'RegionName': 'Lancaster', 'Recent_Month_tx_rental': 2052.43954248366, 'Recent_Month_home_values': 280067.8909061183, 'cap_rate': 8.794037199380313, 'latitude': 32.5922, 'longitude': -96.7739}
# {'_id': ObjectId('6617354d90c281365cdfd4b7'), 'RegionName': 'Belton', 'Recent_Month_tx_rental': 1590.6944444444443, 'Recent_Month_home_values': 318646.16361174185, 'cap_rate': 5.990448187724531, 'latitude': 31.0525, 'longitude': -97.479}
# {'_id': ObjectId('6617354d90c281365cdfd4b8'), 'RegionName': 'Burleson', 'Recent_Month_tx_rental': 2010.98717948718, 'Recent_Month_home_values': 337353.926726617, 'cap_rate': 7.15327264395591, 'latitude': 32.517, 'longitude': -97.3344}
# {'_id': ObjectId('6617354d90c281365cdfd4b9'), 'RegionName': 'Haltom City', 'Recent_Month_tx_rental': 1485.1805555555557, 'Recent_Month_home_values': 246114.79693610643, 'cap_rate': 7.2414039661717124, 'latitude': 32.8176, 'longitude': -97.2707}
# {'_id': ObjectId('6617354d90c281365cdfd4ba'), 'RegionName': 'The Colony', 'Recent_Month_tx_rental': 1900.747162022704, 'Recent_Month_home_values': 411675.21283502335, 'cap_rate': 5.540524479770663, 'latitude': 33.0925, 'longitude': -96.8976}
# {'_id': ObjectId('6617354d90c281365cdfd4bb'), 'RegionName': 'Coppell', 'Recent_Month_tx_rental': 1997.6247863247863, 'Recent_Month_home_values': 620008.4479040653, 'cap_rate': 3.8663178730762353, 'latitude': 32.9639, 'longitude': -96.9903}
# {'_id': ObjectId('6617354d90c281365cdfd4bc'), 'RegionName': 'Cibolo', 'Recent_Month_tx_rental': 2004.879365079365, 'Recent_Month_home_values': 337569.78424193355, 'cap_rate': 7.126986331131405, 'latitude': 29.5634, 'longitude': -98.2115}
# {'_id': ObjectId('6617354d90c281365cdfd4bd'), 'RegionName': 'Keller', 'Recent_Month_tx_rental': 1828.056818181818, 'Recent_Month_home_values': 623284.7302860284, 'cap_rate': 3.519528195101935, 'latitude': 32.9335, 'longitude': -97.2256}
# {'_id': ObjectId('6617354d90c281365cdfd4be'), 'RegionName': 'Friendswood', 'Recent_Month_tx_rental': 2076.1111111111118, 'Recent_Month_home_values': 436444.0867479588, 'cap_rate': 5.7082531508143655, 'latitude': 29.511, 'longitude': -95.1981}
# {'_id': ObjectId('6617354d90c281365cdfd4bf'), 'RegionName': 'Duncanville', 'Recent_Month_tx_rental': 1584.0777777777778, 'Recent_Month_home_values': 279435.0577669971, 'cap_rate': 6.802630094175105, 'latitude': 32.646, 'longitude': -96.9127}
# {'_id': ObjectId('6617354d90c281365cdfd4c0'), 'RegionName': 'Hurst', 'Recent_Month_tx_rental': 1463.8174603174602, 'Recent_Month_home_values': 332588.9204892816, 'cap_rate': 5.281537790846409, 'latitude': 32.8353, 'longitude': -97.1809}
# {'_id': ObjectId('6617354d90c281365cdfd4c1'), 'RegionName': 'Kerrville', 'Recent_Month_tx_rental': 1778.9444444444443, 'Recent_Month_home_values': 347887.6114176559, 'cap_rate': 6.136272932037476, 'latitude': 30.0398, 'longitude': -99.132}
# {'_id': ObjectId('6617354d90c281365cdfd4c2'), 'RegionName': 'Copperas Cove', 'Recent_Month_tx_rental': 1184.9263157894736, 'Recent_Month_home_values': 217838.8712135347, 'cap_rate': 6.527354695818046, 'latitude': 31.1192, 'longitude': -97.914}
# {'_id': ObjectId('6617354d90c281365cdfd4c3'), 'RegionName': 'Manor', 'Recent_Month_tx_rental': 1886.9, 'Recent_Month_home_values': 338931.61449584697, 'cap_rate': 6.680639701811426, 'latitude': 30.3562, 'longitude': -97.5227}
# {'_id': ObjectId('6617354d90c281365cdfd4c4'), 'RegionName': 'Greenville', 'Recent_Month_tx_rental': 1473.0555555555557, 'Recent_Month_home_values': 243591.0711716196, 'cap_rate': 7.256697292575537, 'latitude': 33.1116, 'longitude': -96.1099}
# {'_id': ObjectId('6617354d90c281365cdfd4c5'), 'RegionName': 'Hutto', 'Recent_Month_tx_rental': 1932.59477124183, 'Recent_Month_home_values': 359371.98079827003, 'cap_rate': 6.453240234084938, 'latitude': 30.5396, 'longitude': -97.544}
# {'_id': ObjectId('6617354d90c281365cdfd4c6'), 'RegionName': 'Midlothian', 'Recent_Month_tx_rental': 2323.972222222222, 'Recent_Month_home_values': 446720.7104019825, 'cap_rate': 6.2427521306482285, 'latitude': 32.4669, 'longitude': -96.989}
# {'_id': ObjectId('6617354d90c281365cdfd4c7'), 'RegionName': 'Buda', 'Recent_Month_tx_rental': 1619.2139894419306, 'Recent_Month_home_values': 389574.28015698056, 'cap_rate': 4.987641346721745, 'latitude': 30.0758, 'longitude': -97.8487}
# {'_id': ObjectId('6617354d90c281365cdfd4c8'), 'RegionName': 'Magnolia', 'Recent_Month_tx_rental': 1852.9166666666667, 'Recent_Month_home_values': 331478.97413521906, 'cap_rate': 6.7078161014610105, 'latitude': 30.2115, 'longitude': -95.742}
# {'_id': ObjectId('6617354d90c281365cdfd4c9'), 'RegionName': 'Willis', 'Recent_Month_tx_rental': 1710.711111111111, 'Recent_Month_home_values': 270074.8820043695, 'cap_rate': 7.601052412197741, 'latitude': 30.4314, 'longitude': -95.4831}
# {'_id': ObjectId('6617354d90c281365cdfd4ca'), 'RegionName': 'Orange', 'Recent_Month_tx_rental': 1188.6666666666667, 'Recent_Month_home_values': 156822.6386869465, 'cap_rate': 9.095625554722474, 'latitude': 30.1226, 'longitude': -93.7607}
# {'_id': ObjectId('6617354d90c281365cdfd4cb'), 'RegionName': 'Denison', 'Recent_Month_tx_rental': 1311.8333333333333, 'Recent_Month_home_values': 220771.0928511025, 'cap_rate': 7.130462506075051, 'latitude': 33.7672, 'longitude': -96.5808}
# {'_id': ObjectId('6617354d90c281365cdfd4cc'), 'RegionName': 'Angleton', 'Recent_Month_tx_rental': 1350.0, 'Recent_Month_home_values': 228582.732458774, 'cap_rate': 7.087149508514055, 'latitude': 29.1721, 'longitude': -95.4293}
# {'_id': ObjectId('6617354d90c281365cdfd4cd'), 'RegionName': 'Bastrop', 'Recent_Month_tx_rental': 1778.75, 'Recent_Month_home_values': 359477.7239089748, 'cap_rate': 5.937781002921026, 'latitude': 30.1113, 'longitude': -97.3176}
# {'_id': ObjectId('6617354d90c281365cdfd4ce'), 'RegionName': 'Terrell', 'Recent_Month_tx_rental': 1750.0, 'Recent_Month_home_values': 274348.7450749394, 'cap_rate': 7.654490999863612, 'latitude': 32.734, 'longitude': -96.2931}
# {'_id': ObjectId('6617354d90c281365cdfd4cf'), 'RegionName': 'Farmers Branch', 'Recent_Month_tx_rental': 1732.949376114082, 'Recent_Month_home_values': 376958.740189105, 'cap_rate': 5.516622987156837, 'latitude': 32.9272, 'longitude': -96.8804}
# {'_id': ObjectId('6617354d90c281365cdfd4d0'), 'RegionName': 'Prosper', 'Recent_Month_tx_rental': 1741.123015873016, 'Recent_Month_home_values': 805801.911691288, 'cap_rate': 2.5928799482025457, 'latitude': 33.2394, 'longitude': -96.8087}
# {'_id': ObjectId('6617354d90c281365cdfd4d1'), 'RegionName': 'Big Spring', 'Recent_Month_tx_rental': 1000.0, 'Recent_Month_home_values': 133447.43414517585, 'cap_rate': 8.99230478043163, 'latitude': 32.2389, 'longitude': -101.4799}
# {'_id': ObjectId('6617354d90c281365cdfd4d2'), 'RegionName': 'Harker Heights', 'Recent_Month_tx_rental': 1423.252564102564, 'Recent_Month_home_values': 300442.5719562165, 'cap_rate': 5.684624072423297, 'latitude': 31.0572, 'longitude': -97.6446}
# {'_id': ObjectId('6617354d90c281365cdfd4d3'), 'RegionName': 'La Porte', 'Recent_Month_tx_rental': 1809.3333333333333, 'Recent_Month_home_values': 249103.3572939209, 'cap_rate': 8.71606076925799, 'latitude': 29.6689, 'longitude': -95.0484}
# {'_id': ObjectId('6617354d90c281365cdfd4d4'), 'RegionName': 'Schertz', 'Recent_Month_tx_rental': 1647.7166666666665, 'Recent_Month_home_values': 325051.54595145467, 'cap_rate': 6.082912155401029, 'latitude': 29.565, 'longitude': -98.2535}
# {'_id': ObjectId('6617354d90c281365cdfd4d5'), 'RegionName': 'Crowley', 'Recent_Month_tx_rental': 2110.577380952381, 'Recent_Month_home_values': 317776.72630882193, 'cap_rate': 7.970038858923653, 'latitude': 32.5781, 'longitude': -97.3585}
# {'_id': ObjectId('6617354d90c281365cdfd4d6'), 'RegionName': 'Southlake', 'Recent_Month_tx_rental': 2700.0, 'Recent_Month_home_values': 1194729.6260506257, 'cap_rate': 2.7119106527142467, 'latitude': 32.9545, 'longitude': -97.1503}
# {'_id': ObjectId('6617354d90c281365cdfd4d7'), 'RegionName': 'Lake Jackson', 'Recent_Month_tx_rental': 1365.6666666666667, 'Recent_Month_home_values': 258301.8989919876, 'cap_rate': 6.344513944323865, 'latitude': 29.0516, 'longitude': -95.4521}
# {'_id': ObjectId('6617354d90c281365cdfd4d8'), 'RegionName': 'Woodway', 'Recent_Month_tx_rental': 1585.111111111111, 'Recent_Month_home_values': 365522.96264040895, 'cap_rate': 5.203868231951812, 'latitude': 31.4988, 'longitude': -97.2314}
# {'_id': ObjectId('6617354d90c281365cdfd4d9'), 'RegionName': 'Azle', 'Recent_Month_tx_rental': 1505.6944444444443, 'Recent_Month_home_values': 327974.40030796366, 'cap_rate': 5.509068182262824, 'latitude': 32.8955, 'longitude': -97.5379}
# {'_id': ObjectId('6617354d90c281365cdfd4da'), 'RegionName': 'Canyon Lake', 'Recent_Month_tx_rental': 1742.9166666666667, 'Recent_Month_home_values': 442986.19215762336, 'cap_rate': 4.721366121623499, 'latitude': 29.8761, 'longitude': -98.2611}
# {'_id': ObjectId('6617354d90c281365cdfd4db'), 'RegionName': 'Stephenville', 'Recent_Month_tx_rental': 1458.3333333333333, 'Recent_Month_home_values': 287156.2121508231, 'cap_rate': 6.094243920033488, 'latitude': 32.2147, 'longitude': -98.2205}
# {'_id': ObjectId('6617354d90c281365cdfd4dc'), 'RegionName': 'Celina', 'Recent_Month_tx_rental': 2200.7314814814813, 'Recent_Month_home_values': 576994.7052121259, 'cap_rate': 4.576953226645099, 'latitude': 33.3154, 'longitude': -96.7941}
# {'_id': ObjectId('6617354d90c281365cdfd4dd'), 'RegionName': 'Royse City', 'Recent_Month_tx_rental': 2180.4880952380954, 'Recent_Month_home_values': 337460.0760617717, 'cap_rate': 7.753763777990589, 'latitude': 32.9762, 'longitude': -96.3175}
# {'_id': ObjectId('6617354d90c281365cdfd4de'), 'RegionName': 'Brenham', 'Recent_Month_tx_rental': 1416.6666666666667, 'Recent_Month_home_values': 309753.14868012554, 'cap_rate': 5.488241224484043, 'latitude': 30.1584, 'longitude': -96.3966}
# {'_id': ObjectId('6617354d90c281365cdfd4df'), 'RegionName': 'Aubrey', 'Recent_Month_tx_rental': 2106.952380952381, 'Recent_Month_home_values': 385020.54014386097, 'cap_rate': 6.566773960158476, 'latitude': 33.2874, 'longitude': -96.9622}
# {'_id': ObjectId('6617354d90c281365cdfd4e0'), 'RegionName': 'Crosby', 'Recent_Month_tx_rental': 1959.4444444444443, 'Recent_Month_home_values': 264932.8896589693, 'cap_rate': 8.875203589709265, 'latitude': 29.9146, 'longitude': -95.0591}
# {'_id': ObjectId('6617354d90c281365cdfd4e1'), 'RegionName': 'Saginaw', 'Recent_Month_tx_rental': 1719.9603174603174, 'Recent_Month_home_values': 309995.543577747, 'cap_rate': 6.658006618842702, 'latitude': 32.8657, 'longitude': -97.3654}
# {'_id': ObjectId('6617354d90c281365cdfd4e2'), 'RegionName': 'University Park', 'Recent_Month_tx_rental': 3943.055555555555, 'Recent_Month_home_values': 2129051.154935855, 'cap_rate': 2.2224297691002284, 'latitude': 32.8506, 'longitude': -96.7937}
# {'_id': ObjectId('6617354d90c281365cdfd4e3'), 'RegionName': 'Sachse', 'Recent_Month_tx_rental': 1959.4666666666665, 'Recent_Month_home_values': 451767.11627156497, 'cap_rate': 5.204805563109106, 'latitude': 32.9726, 'longitude': -96.5793}
# {'_id': ObjectId('6617354d90c281365cdfd4e4'), 'RegionName': 'Gatesville', 'Recent_Month_tx_rental': 1022.5, 'Recent_Month_home_values': 228918.0318668792, 'cap_rate': 5.359997157032728, 'latitude': 31.4445, 'longitude': -97.7317}
# {'_id': ObjectId('6617354d90c281365cdfd4e5'), 'RegionName': 'Manvel', 'Recent_Month_tx_rental': 1926.3333333333333, 'Recent_Month_home_values': 419087.8587315599, 'cap_rate': 5.515788519849865, 'latitude': 29.4798, 'longitude': -95.3635}
# {'_id': ObjectId('6617354d90c281365cdfd4e6'), 'RegionName': 'Haslet', 'Recent_Month_tx_rental': 2150.4030303030304, 'Recent_Month_home_values': 399841.8955123546, 'cap_rate': 6.453760011959283, 'latitude': 32.9609, 'longitude': -97.3387}
# {'_id': ObjectId('6617354d90c281365cdfd4e7'), 'RegionName': 'Ennis', 'Recent_Month_tx_rental': 1797.2222222222224, 'Recent_Month_home_values': 251365.03690778403, 'cap_rate': 8.579819585083598, 'latitude': 32.3254, 'longitude': -96.6347}
# {'_id': ObjectId('6617354d90c281365cdfd4e8'), 'RegionName': 'Fresno', 'Recent_Month_tx_rental': 2030.7666666666669, 'Recent_Month_home_values': 278194.42098575964, 'cap_rate': 8.759773080153693, 'latitude': 29.5357, 'longitude': -95.4696}
# {'_id': ObjectId('6617354d90c281365cdfd4e9'), 'RegionName': 'Watauga', 'Recent_Month_tx_rental': 2000.5555555555557, 'Recent_Month_home_values': 279387.39615502866, 'cap_rate': 8.592609042873809, 'latitude': 32.8719, 'longitude': -97.2515}
# {'_id': ObjectId('6617354d90c281365cdfd4ea'), 'RegionName': 'Anna', 'Recent_Month_tx_rental': 2128.015873015873, 'Recent_Month_home_values': 359863.08120312594, 'cap_rate': 7.096085097369709, 'latitude': 33.3472, 'longitude': -96.5508}
# {'_id': ObjectId('6617354d90c281365cdfd4eb'), 'RegionName': 'Benbrook', 'Recent_Month_tx_rental': 1563.4126984126983, 'Recent_Month_home_values': 314828.72138685954, 'cap_rate': 5.959098108427993, 'latitude': 32.6788, 'longitude': -97.4637}
# {'_id': ObjectId('6617354d90c281365cdfd4ec'), 'RegionName': 'Horizon City', 'Recent_Month_tx_rental': 1462.5, 'Recent_Month_home_values': 203479.6865189545, 'cap_rate': 8.624939570252968, 'latitude': 31.6799, 'longitude': -106.1903}
# {'_id': ObjectId('6617354d90c281365cdfd4ed'), 'RegionName': 'Princeton', 'Recent_Month_tx_rental': 1937.547619047619, 'Recent_Month_home_values': 331470.2569878842, 'cap_rate': 7.014376384732847, 'latitude': 33.1778, 'longitude': -96.5044}
# {'_id': ObjectId('6617354d90c281365cdfd4ee'), 'RegionName': 'Corsicana', 'Recent_Month_tx_rental': 1307.8555555555556, 'Recent_Month_home_values': 162578.37672653724, 'cap_rate': 9.653354266825406, 'latitude': 32.0824, 'longitude': -96.4665}
# {'_id': ObjectId('6617354d90c281365cdfd4ef'), 'RegionName': 'Canyon', 'Recent_Month_tx_rental': 959.1666666666666, 'Recent_Month_home_values': 269054.068948081, 'cap_rate': 4.27795054168873, 'latitude': 34.9911, 'longitude': -101.919}
# {'_id': ObjectId('6617354d90c281365cdfd4f0'), 'RegionName': 'Corinth', 'Recent_Month_tx_rental': 1766.7777777777776, 'Recent_Month_home_values': 416989.0260099645, 'cap_rate': 5.084386401292655, 'latitude': 33.1434, 'longitude': -97.0682}
# {'_id': ObjectId('6617354d90c281365cdfd4f1'), 'RegionName': 'Universal City', 'Recent_Month_tx_rental': 1104.600641025641, 'Recent_Month_home_values': 274028.0210413384, 'cap_rate': 4.8371723599420084, 'latitude': 29.5521, 'longitude': -98.3074}
# {'_id': ObjectId('6617354d90c281365cdfd4f2'), 'RegionName': 'Pecan Grove', 'Recent_Month_tx_rental': 1843.5, 'Recent_Month_home_values': 398311.24001103226, 'cap_rate': 5.553948213810706, 'latitude': 29.6235, 'longitude': -95.733}
# {'_id': ObjectId('6617354d90c281365cdfd4f3'), 'RegionName': 'Nederland', 'Recent_Month_tx_rental': 1188.8666666666666, 'Recent_Month_home_values': 190736.1313388402, 'cap_rate': 7.4796525964217695, 'latitude': 29.9707, 'longitude': -94.0015}
# {'_id': ObjectId('6617354d90c281365cdfd4f4'), 'RegionName': 'Lindale', 'Recent_Month_tx_rental': 1446.6666666666663, 'Recent_Month_home_values': 289705.3808012535, 'cap_rate': 5.9922946380859505, 'latitude': 32.4933, 'longitude': -95.4069}
# {'_id': ObjectId('6617354d90c281365cdfd4f5'), 'RegionName': 'Dripping Springs', 'Recent_Month_tx_rental': 2068.5333333333333, 'Recent_Month_home_values': 722702.9260860536, 'cap_rate': 3.4346616160018635, 'latitude': 30.196, 'longitude': -98.0938}
# {'_id': ObjectId('6617354d90c281365cdfd4f6'), 'RegionName': 'Fulshear', 'Recent_Month_tx_rental': 2318.333333333333, 'Recent_Month_home_values': 530162.5849251843, 'cap_rate': 5.247446875928808, 'latitude': 29.693, 'longitude': -95.8804}
# {'_id': ObjectId('6617354d90c281365cdfd4f7'), 'RegionName': 'Cinco Ranch', 'Recent_Month_tx_rental': 1809.7370370370368, 'Recent_Month_home_values': 523441.1457270966, 'cap_rate': 4.148860788213011, 'latitude': 29.7395, 'longitude': -95.7607}
# {'_id': ObjectId('6617354d90c281365cdfd4f8'), 'RegionName': 'Taylor', 'Recent_Month_tx_rental': 1581.6666666666667, 'Recent_Month_home_values': 301035.0960868863, 'cap_rate': 6.304912698458885, 'latitude': 30.5729, 'longitude': -97.4268}
# {'_id': ObjectId('6617354d90c281365cdfd4f9'), 'RegionName': 'Timberwood Park', 'Recent_Month_tx_rental': 2401.666666666667, 'Recent_Month_home_values': 512730.85728646326, 'cap_rate': 5.620882689316715, 'latitude': 29.6995, 'longitude': -98.4838}
# {'_id': ObjectId('6617354d90c281365cdfd4fa'), 'RegionName': 'Joshua', 'Recent_Month_tx_rental': 1250.0, 'Recent_Month_home_values': 330810.0195197281, 'cap_rate': 4.534324571479754, 'latitude': 32.458, 'longitude': -97.3849}
# {'_id': ObjectId('6617354d90c281365cdfd4fb'), 'RegionName': 'Springtown', 'Recent_Month_tx_rental': 1474.0, 'Recent_Month_home_values': 383005.9018876088, 'cap_rate': 4.61820559757078, 'latitude': 32.9693, 'longitude': -97.6804}
# {'_id': ObjectId('6617354d90c281365cdfd4fc'), 'RegionName': 'Sanger', 'Recent_Month_tx_rental': 1927.5, 'Recent_Month_home_values': 357373.5802771524, 'cap_rate': 6.472218786308178, 'latitude': 33.3715, 'longitude': -97.1678}
# {'_id': ObjectId('6617354d90c281365cdfd4fd'), 'RegionName': 'Lumberton', 'Recent_Month_tx_rental': 1761.6666666666667, 'Recent_Month_home_values': 266331.5303367953, 'cap_rate': 7.937475511542683, 'latitude': 30.2562, 'longitude': -94.207}
# {'_id': ObjectId('6617354d90c281365cdfd4fe'), 'RegionName': 'Dickinson', 'Recent_Month_tx_rental': 1836.25, 'Recent_Month_home_values': 255523.8870807509, 'cap_rate': 8.623459924526147, 'latitude': 29.4548, 'longitude': -95.0589}
# {'_id': ObjectId('6617354d90c281365cdfd4ff'), 'RegionName': 'Silsbee', 'Recent_Month_tx_rental': 812.5, 'Recent_Month_home_values': 154358.59478001602, 'cap_rate': 6.316460715320195, 'latitude': 30.3456, 'longitude': -94.1764}
# {'_id': ObjectId('6617354d90c281365cdfd500'), 'RegionName': 'Groves', 'Recent_Month_tx_rental': 1287.5, 'Recent_Month_home_values': 158805.22801158667, 'cap_rate': 9.72889884889227, 'latitude': 29.9457, 'longitude': -93.9164}
# {'_id': ObjectId('6617354d90c281365cdfd501'), 'RegionName': 'White Settlement', 'Recent_Month_tx_rental': 1747.7777777777776, 'Recent_Month_home_values': 221458.5646181812, 'cap_rate': 9.470545142154991, 'latitude': 32.7554, 'longitude': -97.4605}
# {'_id': ObjectId('6617354d90c281365cdfd502'), 'RegionName': 'Bellaire', 'Recent_Month_tx_rental': 2272.5, 'Recent_Month_home_values': 1035851.9755036696, 'cap_rate': 2.63261553242106, 'latitude': 29.704, 'longitude': -95.4621}
# {'_id': ObjectId('6617354d90c281365cdfd503'), 'RegionName': 'La Marque', 'Recent_Month_tx_rental': 1638.0833333333333, 'Recent_Month_home_values': 213703.3581487793, 'cap_rate': 9.198264440147396, 'latitude': 29.3683, 'longitude': -94.9941}
# {'_id': ObjectId('6617354d90c281365cdfd504'), 'RegionName': 'Marble Falls', 'Recent_Month_tx_rental': 1588.0, 'Recent_Month_home_values': 430109.6048575859, 'cap_rate': 4.430498594959221, 'latitude': 30.5649, 'longitude': -98.2768}
# {'_id': ObjectId('6617354d90c281365cdfd505'), 'RegionName': 'Liberty Hill', 'Recent_Month_tx_rental': 2188.194444444445, 'Recent_Month_home_values': 498864.7278375517, 'cap_rate': 5.2636179445190185, 'latitude': 30.6638, 'longitude': -97.9063}
# {'_id': ObjectId('6617354d90c281365cdfd506'), 'RegionName': 'Stafford', 'Recent_Month_tx_rental': 1526.1794871794873, 'Recent_Month_home_values': 296345.92795437534, 'cap_rate': 6.179991732153461, 'latitude': 29.6271, 'longitude': -95.5654}
# {'_id': ObjectId('6617354d90c281365cdfd507'), 'RegionName': 'Roanoke', 'Recent_Month_tx_rental': 1715.7298701298705, 'Recent_Month_home_values': 429139.7050910528, 'cap_rate': 4.79768201294495, 'latitude': 33.0144, 'longitude': -97.2276}
# {'_id': ObjectId('6617354d90c281365cdfd508'), 'RegionName': 'Addison', 'Recent_Month_tx_rental': 1623.8339641155032, 'Recent_Month_home_values': 477619.1810647105, 'cap_rate': 4.079820983308869, 'latitude': 32.959, 'longitude': -96.8355}
# {'_id': ObjectId('6617354d90c281365cdfd509'), 'RegionName': 'Wimberley', 'Recent_Month_tx_rental': 2311.25, 'Recent_Month_home_values': 541902.4243006848, 'cap_rate': 5.118080074247962, 'latitude': 29.9848, 'longitude': -98.0906}
# {'_id': ObjectId('6617354d90c281365cdfd50a'), 'RegionName': 'Red Oak', 'Recent_Month_tx_rental': 2386.0, 'Recent_Month_home_values': 338326.9451961824, 'cap_rate': 8.462819886662421, 'latitude': 32.5212, 'longitude': -96.7866}
# {'_id': ObjectId('6617354d90c281365cdfd50b'), 'RegionName': 'Rockport', 'Recent_Month_tx_rental': 1383.75, 'Recent_Month_home_values': 325380.59009463125, 'cap_rate': 5.1032546210487615, 'latitude': 28.029, 'longitude': -97.0722}
# {'_id': ObjectId('6617354d90c281365cdfd50c'), 'RegionName': 'Lakeway', 'Recent_Month_tx_rental': 2862.083333333333, 'Recent_Month_home_values': 768484.8729705373, 'cap_rate': 4.469183611544784, 'latitude': 30.3544, 'longitude': -97.9864}
# {'_id': ObjectId('6617354d90c281365cdfd50d'), 'RegionName': 'Fate', 'Recent_Month_tx_rental': 2341.1111111111118, 'Recent_Month_home_values': 363838.7111299041, 'cap_rate': 7.721370066997342, 'latitude': 32.943, 'longitude': -96.3858}
# {'_id': ObjectId('6617354d90c281365cdfd50e'), 'RegionName': 'Whitehouse', 'Recent_Month_tx_rental': 1525.5555555555557, 'Recent_Month_home_values': 280875.3787784552, 'cap_rate': 6.517718550584077, 'latitude': 32.2222, 'longitude': -95.221}
# {'_id': ObjectId('6617354d90c281365cdfd50f'), 'RegionName': 'Bonham', 'Recent_Month_tx_rental': 1195.0, 'Recent_Month_home_values': 205896.2686069549, 'cap_rate': 6.964672112331624, 'latitude': 33.588, 'longitude': -96.1901}
# {'_id': ObjectId('6617354d90c281365cdfd510'), 'RegionName': 'Seabrook', 'Recent_Month_tx_rental': 2060.5, 'Recent_Month_home_values': 347818.30969519384, 'cap_rate': 7.108883951988703, 'latitude': 29.5751, 'longitude': -95.0235}
# {'_id': ObjectId('6617354d90c281365cdfd511'), 'RegionName': 'Glenn Heights', 'Recent_Month_tx_rental': 2370.055555555555, 'Recent_Month_home_values': 330060.6934103435, 'cap_rate': 8.616799041656314, 'latitude': 32.5506, 'longitude': -96.8548}
# {'_id': ObjectId('6617354d90c281365cdfd512'), 'RegionName': 'Sealy', 'Recent_Month_tx_rental': 1750.0, 'Recent_Month_home_values': 320355.1002335342, 'cap_rate': 6.555225743149183, 'latitude': 29.7662, 'longitude': -96.163}
# {'_id': ObjectId('6617354d90c281365cdfd513'), 'RegionName': 'Live Oak', 'Recent_Month_tx_rental': 1413.1015873015874, 'Recent_Month_home_values': 256648.39333361364, 'cap_rate': 6.607179116674461, 'latitude': 29.5545, 'longitude': -98.3404}
# {'_id': ObjectId('6617354d90c281365cdfd514'), 'RegionName': 'Port Neches', 'Recent_Month_tx_rental': 1523.5, 'Recent_Month_home_values': 214073.6980936233, 'cap_rate': 8.540049601051187, 'latitude': 29.9765, 'longitude': -93.9459}
# {'_id': ObjectId('6617354d90c281365cdfd515'), 'RegionName': 'Webster', 'Recent_Month_tx_rental': 1364.642857142857, 'Recent_Month_home_values': 263826.6587066078, 'cap_rate': 6.206997566506398, 'latitude': 29.5317, 'longitude': -95.1188}
# {'_id': ObjectId('6617354d90c281365cdfd516'), 'RegionName': 'Hewitt', 'Recent_Month_tx_rental': 1589.375, 'Recent_Month_home_values': 295759.63763037504, 'cap_rate': 6.448648690811494, 'latitude': 31.452, 'longitude': -97.196}
# {'_id': ObjectId('6617354d90c281365cdfd517'), 'RegionName': 'Melissa', 'Recent_Month_tx_rental': 2192.922222222222, 'Recent_Month_home_values': 466915.9557604271, 'cap_rate': 5.635932193366472, 'latitude': 33.2891, 'longitude': -96.5573}
# {'_id': ObjectId('6617354d90c281365cdfd518'), 'RegionName': 'Justin', 'Recent_Month_tx_rental': 2120.555555555556, 'Recent_Month_home_values': 374825.2079598426, 'cap_rate': 6.788942185924948, 'latitude': 33.0882, 'longitude': -97.3041}
# {'_id': ObjectId('6617354d90c281365cdfd519'), 'RegionName': 'Robinson', 'Recent_Month_tx_rental': 1898.75, 'Recent_Month_home_values': 299320.14629503986, 'cap_rate': 7.612250722856732, 'latitude': 31.4501, 'longitude': -97.1201}
# {'_id': ObjectId('6617354d90c281365cdfd51a'), 'RegionName': 'Crandall', 'Recent_Month_tx_rental': 1874.0, 'Recent_Month_home_values': 297218.1949671825, 'cap_rate': 7.5661585935151185, 'latitude': 32.6233, 'longitude': -96.4525}
# {'_id': ObjectId('6617354d90c281365cdfd51b'), 'RegionName': 'Hitchcock', 'Recent_Month_tx_rental': 1500.0, 'Recent_Month_home_values': 191325.77971408295, 'cap_rate': 9.408036923669764, 'latitude': 29.2949, 'longitude': -95.03}
# {'_id': ObjectId('6617354d90c281365cdfd51c'), 'RegionName': 'Clute', 'Recent_Month_tx_rental': 948.0555555555557, 'Recent_Month_home_values': 187964.14603496745, 'cap_rate': 6.0525727414792385, 'latitude': 29.0256, 'longitude': -95.3975}
# {'_id': ObjectId('6617354d90c281365cdfd51d'), 'RegionName': 'Fairview', 'Recent_Month_tx_rental': 1770.452380952381, 'Recent_Month_home_values': 650002.1587338374, 'cap_rate': 3.268516617362211, 'latitude': 33.1399, 'longitude': -96.6117}
# {'_id': ObjectId('6617354d90c281365cdfd51e'), 'RegionName': 'Jarrell', 'Recent_Month_tx_rental': 1853.2083333333333, 'Recent_Month_home_values': 281632.0038030422, 'cap_rate': 7.896297189133511, 'latitude': 30.8103, 'longitude': -97.6144}
# {'_id': ObjectId('6617354d90c281365cdfd51f'), 'RegionName': 'Selma', 'Recent_Month_tx_rental': 1468.038888888889, 'Recent_Month_home_values': 300623.2058892713, 'cap_rate': 5.859982303946073, 'latitude': 29.5866, 'longitude': -98.3132}
# {'_id': ObjectId('6617354d90c281365cdfd520'), 'RegionName': 'Richland Hills', 'Recent_Month_tx_rental': 1700.0, 'Recent_Month_home_values': 276215.56338910194, 'cap_rate': 7.38553604644744, 'latitude': 32.8095, 'longitude': -97.2273}
# {'_id': ObjectId('6617354d90c281365cdfd521'), 'RegionName': 'Bee Cave', 'Recent_Month_tx_rental': 2047.673015873016, 'Recent_Month_home_values': 913363.851620084, 'cap_rate': 2.6902834119054897, 'latitude': 30.3084, 'longitude': -97.9629}
# {'_id': ObjectId('6617354d90c281365cdfd522'), 'RegionName': 'Wolfforth', 'Recent_Month_tx_rental': 1719.5833333333337, 'Recent_Month_home_values': 266119.34503743943, 'cap_rate': 7.754039826415826, 'latitude': 33.5147, 'longitude': -102.0067}
# {'_id': ObjectId('6617354d90c281365cdfd523'), 'RegionName': 'Bacliff', 'Recent_Month_tx_rental': 1462.5, 'Recent_Month_home_values': 204154.3463062942, 'cap_rate': 8.596437116097256, 'latitude': 29.5085, 'longitude': -94.9888}
# {'_id': ObjectId('6617354d90c281365cdfd524'), 'RegionName': 'Kennedale', 'Recent_Month_tx_rental': 1433.3333333333337, 'Recent_Month_home_values': 387606.3082814005, 'cap_rate': 4.437492278250765, 'latitude': 32.6434, 'longitude': -97.2172}
# {'_id': ObjectId('6617354d90c281365cdfd525'), 'RegionName': 'Lago Vista', 'Recent_Month_tx_rental': 1922.5, 'Recent_Month_home_values': 419310.8534085038, 'cap_rate': 5.501884774140247, 'latitude': 30.4519, 'longitude': -97.9908}
# {'_id': ObjectId('6617354d90c281365cdfd526'), 'RegionName': 'Krum', 'Recent_Month_tx_rental': 2158.333333333333, 'Recent_Month_home_values': 346889.5789438102, 'cap_rate': 7.4663528604286284, 'latitude': 33.2655, 'longitude': -97.2252}
# {'_id': ObjectId('6617354d90c281365cdfd527'), 'RegionName': 'Ingleside', 'Recent_Month_tx_rental': 1178.4444444444443, 'Recent_Month_home_values': 206462.6351057409, 'cap_rate': 6.849342655193166, 'latitude': 27.8703, 'longitude': -97.2075}
# {'_id': ObjectId('6617354d90c281365cdfd528'), 'RegionName': 'Trophy Club', 'Recent_Month_tx_rental': 3017.5, 'Recent_Month_home_values': 681712.8495634914, 'cap_rate': 5.311620577958253, 'latitude': 33.004, 'longitude': -97.1899}
# {'_id': ObjectId('6617354d90c281365cdfd529'), 'RegionName': 'Jersey Village', 'Recent_Month_tx_rental': 1238.5, 'Recent_Month_home_values': 380914.3439576495, 'cap_rate': 3.9016645699360626, 'latitude': 29.8903, 'longitude': -95.5721}
# {'_id': ObjectId('6617354d90c281365cdfd52a'), 'RegionName': 'Alamo Heights', 'Recent_Month_tx_rental': 1661.8333333333333, 'Recent_Month_home_values': 708463.7310018496, 'cap_rate': 2.814822993380297, 'latitude': 29.4828, 'longitude': -98.4682}
# {'_id': ObjectId('6617354d90c281365cdfd52b'), 'RegionName': 'Cross Roads', 'Recent_Month_tx_rental': 2290.0, 'Recent_Month_home_values': 356035.5323154282, 'cap_rate': 7.718330757968901, 'latitude': 33.2291, 'longitude': -96.9985}
# {'_id': ObjectId('6617354d90c281365cdfd52c'), 'RegionName': 'Bridge City', 'Recent_Month_tx_rental': 1260.0, 'Recent_Month_home_values': 196083.6048967863, 'cap_rate': 7.710996545559637, 'latitude': 30.0298, 'longitude': -93.8406}
# {'_id': ObjectId('6617354d90c281365cdfd52d'), 'RegionName': 'Windcrest', 'Recent_Month_tx_rental': 1105.8333333333333, 'Recent_Month_home_values': 318091.6450652438, 'cap_rate': 4.171753708676689, 'latitude': 29.515, 'longitude': -98.3818}
# {'_id': ObjectId('6617354d90c281365cdfd52e'), 'RegionName': 'Lavon', 'Recent_Month_tx_rental': 2405.0, 'Recent_Month_home_values': 378896.9091867884, 'cap_rate': 7.616847564668998, 'latitude': 33.0252, 'longitude': -96.4381}
# {'_id': ObjectId('6617354d90c281365cdfd52f'), 'RegionName': 'Brookshire', 'Recent_Month_tx_rental': 2287.777777777778, 'Recent_Month_home_values': 340086.74696718523, 'cap_rate': 8.072450213998575, 'latitude': 29.7824, 'longitude': -95.9514}
# {'_id': ObjectId('6617354d90c281365cdfd530'), 'RegionName': 'Iowa Colony', 'Recent_Month_tx_rental': 2470.0, 'Recent_Month_home_values': 333267.7683960433, 'cap_rate': 8.893749354356077, 'latitude': 29.4407, 'longitude': -95.4206}
# {'_id': ObjectId('6617354d90c281365cdfd531'), 'RegionName': 'Willow Park', 'Recent_Month_tx_rental': 1903.1666666666667, 'Recent_Month_home_values': 419204.0385881162, 'cap_rate': 5.447943697517475, 'latitude': 32.7548, 'longitude': -97.6498}
# {'_id': ObjectId('6617354d90c281365cdfd532'), 'RegionName': 'Hudson Oaks', 'Recent_Month_tx_rental': 1470.75, 'Recent_Month_home_values': 525745.7244864338, 'cap_rate': 3.356945987005437, 'latitude': 32.7509, 'longitude': -97.7001}
# {'_id': ObjectId('6617354d90c281365cdfd533'), 'RegionName': 'Kemah', 'Recent_Month_tx_rental': 1441.2222222222224, 'Recent_Month_home_values': 319180.00692773674, 'cap_rate': 5.418468040381436, 'latitude': 29.5309, 'longitude': -95.0196}
# {'_id': ObjectId('6617354d90c281365cdfd534'), 'RegionName': 'Shenandoah', 'Recent_Month_tx_rental': 2005.555555555556, 'Recent_Month_home_values': 416391.09609320574, 'cap_rate': 5.7798225976665805, 'latitude': 30.184, 'longitude': -95.4557}
# {'_id': ObjectId('6617354d90c281365cdfd535'), 'RegionName': 'Sunset Valley', 'Recent_Month_tx_rental': 1619.25, 'Recent_Month_home_values': 999838.1457988574, 'cap_rate': 1.9434145498094482, 'latitude': 30.2258, 'longitude': -97.8158}
# {'_id': ObjectId('6617354d90c281365cdfd536'), 'RegionName': 'South Padre Island', 'Recent_Month_tx_rental': 2350.0, 'Recent_Month_home_values': 443895.8237057352, 'cap_rate': 6.35284192686935, 'latitude': 26.1218, 'longitude': -97.1703}

# %%
collection = db['cap_rates']
data = list(collection.find()) 
cap_rates_df = pd.DataFrame(data)

# Drop the MongoDB ID column if present
cap_rates_df.drop('_id', axis=1, inplace=True)
cap_rates_df
# Out:
#              RegionName  Recent_Month_tx_rental  Recent_Month_home_values  \
# 0                Dallas             1709.807306             307990.336118
# 1               Houston             1572.250076             264626.193654
# 2           San Antonio             1392.620914             253762.224225
# 3                Austin             1719.293768             533719.132333
# 4            Fort Worth             1677.156930             302358.864013
# ..                  ...                     ...                       ...
# 221         Hudson Oaks             1470.750000             525745.724486
# 222               Kemah             1441.222222             319180.006928
# 223          Shenandoah             2005.555556             416391.096093
# 224       Sunset Valley             1619.250000             999838.145799
# 225  South Padre Island             2350.000000             443895.823706
#
#      cap_rate  latitude  longitude
# 0    6.661796   32.7935   -96.7667
# 1    7.129680   29.7860   -95.3885
# 2    6.585476   29.4632   -98.5238
# 3    3.865615   30.3005   -97.7522
# 4    6.656290   32.7817   -97.3474
# ..        ...       ...        ...
# 221  3.356946   32.7509   -97.7001
# 222  5.418468   29.5309   -95.0196
# 223  5.779823   30.1840   -95.4557
# 224  1.943415   30.2258   -97.8158
# 225  6.352842   26.1218   -97.1703
#
# [226 rows x 6 columns]

# %%
# Renaming the columns for clarity
cap_rates_df = cap_rates_df.rename(columns={"Recent_Month_tx_rental": "Rentals",
                                            "Recent_Month_home_values": "Home Values",
                                            "cap_rate": "Cap Rate"})

# Selecting the renamed columns for box plots
columns_to_plot = ["Rentals", "Home Values", "Cap Rate"]

# Creating a figure and axes for subplots
fig, axes = plt.subplots(nrows=1, ncols=len(columns_to_plot), figsize=(18, 5))

# Creating separate box plots for each feature
for i, column in enumerate(columns_to_plot):
    cap_rates_df[[column]].boxplot(ax=axes[i])
    axes[i].set_title(column)

    # Modifying the y-axis label formatting
    if column != "Cap Rate":
        yticklabels = [f"{val:.0f}" for val in axes[i].get_yticks().tolist()]
        axes[i].yaxis.set_major_locator(mticker.FixedLocator(axes[i].get_yticks()))
        axes[i].yaxis.set_major_formatter(mticker.FixedFormatter(yticklabels))
    else:
        axes[i].yaxis.get_major_formatter().set_scientific(False)

# Adding titles and labels
plt.suptitle('Box Plots for Rentals, Home Values, and Cap Rate', fontsize=16)
for ax in axes:
    ax.set_ylabel('Values', fontsize=12)
    ax.set_xlabel('Features', fontsize=12)

# Displaying the plot
plt.tight_layout() 
plt.show()

# %%
# Finding the top 10 highest and lowest values for each feature
top_10_highest_rentals = cap_rates_df.nlargest(10, 'Rentals')
top_10_lowest_rentals = cap_rates_df.nsmallest(10, 'Rentals')

top_10_highest_home_values = cap_rates_df.nlargest(10, 'Home Values')
top_10_lowest_home_values = cap_rates_df.nsmallest(10, 'Home Values')

top_10_highest_cap_rate = cap_rates_df.nlargest(10, 'Cap Rate')
top_10_lowest_cap_rate = cap_rates_df.nsmallest(10, 'Cap Rate')

# %%
# Create subplots for Rentals
fig, axes = plt.subplots(2, 1, figsize=(5, 6))

# Plotting bar charts for top 10 highest and lowest rentals
top_10_highest_rentals = top_10_highest_rentals.sort_values(by='Rentals', ascending=False)
top_10_lowest_rentals = top_10_lowest_rentals.sort_values(by='Rentals', ascending=True)

ax = axes[0]
ax.barh(top_10_highest_rentals['RegionName'], top_10_highest_rentals['Rentals'], color='skyblue')
ax.set_xlabel('Values')
ax.set_ylabel('Region')
ax.set_title('Top 10 Highest Rentals')
ax.invert_yaxis()
ax.set_xticks([0, 1000, 2000, 3000, 4000])
ax.set_xticklabels(['0', '1000', '2000', '3000', '4000'])

ax = axes[1]
ax.barh(top_10_lowest_rentals['RegionName'], top_10_lowest_rentals['Rentals'], color='skyblue')
ax.set_xlabel('Values')
ax.set_ylabel('Region')
ax.set_title('Top 10 Lowest Rentals')
ax.invert_yaxis()
ax.set_xticks([0, 500, 1000, 1500, 2000])
ax.set_xticklabels(['0', '500', '1000', '1500', '2000'])

plt.tight_layout()
plt.show()

# %%
# Create subplots for Home Values
fig, axes = plt.subplots(2, 1, figsize=(5, 6))

# Plotting bar charts for top 10 highest and lowest home values
top_10_highest_home_values = top_10_highest_home_values.sort_values(by='Home Values', ascending=False)
top_10_lowest_home_values = top_10_lowest_home_values.sort_values(by='Home Values', ascending=True)

ax = axes[0]
ax.barh(top_10_highest_home_values['RegionName'], top_10_highest_home_values['Home Values'], color='skyblue')
ax.set_xlabel('Values')
ax.set_ylabel('Region')
ax.set_title('Top 10 Highest Home Values')
ax.invert_yaxis()
ax.set_xticks([0, 500000, 1000000, 1500000, 2000000])
ax.set_xticklabels(['0', '500k', '1M', '1.5M', '2M'])

ax = axes[1]
ax.barh(top_10_lowest_home_values['RegionName'], top_10_lowest_home_values['Home Values'], color='skyblue')
ax.set_xlabel('Values')
ax.set_ylabel('Region')
ax.set_title('Top 10 Lowest Home Values')
ax.invert_yaxis()
ax.set_xticks([0, 50000, 100000, 150000, 200000])
ax.set_xticklabels(['0', '50k', '100k', '150k', '200k'])

plt.tight_layout()
plt.show()

# %%
# Create subplots for Cap Rates
fig, axes = plt.subplots(2, 1, figsize=(5, 6))

# Plotting bar charts for top 10 highest and lowest cap rates
top_10_highest_cap_rate = top_10_highest_cap_rate.sort_values(by='Cap Rate', ascending=False)
top_10_lowest_cap_rate = top_10_lowest_cap_rate.sort_values(by='Cap Rate', ascending=True)

ax = axes[0]
ax.barh(top_10_highest_cap_rate['RegionName'], top_10_highest_cap_rate['Cap Rate'], color='skyblue')
ax.set_xlabel('Values')
ax.set_ylabel('Region')
ax.set_title('Top 10 Highest Cap Rate')
ax.invert_yaxis()
ax.set_xticks([0.0, 2.5, 5.0, 7.5, 10.0, 12.5, 15.0])
ax.set_xticklabels([ '0.0', '2.5', '5.0', '7.5', '10.0', '12.5', '15.0'])

ax = axes[1]
ax.barh(top_10_lowest_cap_rate['RegionName'], top_10_lowest_cap_rate['Cap Rate'], color='skyblue')
ax.set_xlabel('Values')
ax.set_ylabel('Region')
ax.set_title('Top 10 Lowest Cap Rate')
ax.invert_yaxis()
ax.set_xticks([0.0, 1.0, 2.0, 3.0, 4.0])
ax.set_xticklabels([ '0.0', '1.0', '2.0', '3.0', '4.0'])

plt.tight_layout()
plt.show()
